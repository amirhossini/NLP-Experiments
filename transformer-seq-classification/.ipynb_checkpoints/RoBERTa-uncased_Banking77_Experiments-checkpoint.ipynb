# %% [markdown]
# __Project:__ Text Classification <br>
# __Sub-prj:__ Parametric Evaluation - _number of labels & data instances_ <br>
# __Experm:__ Roberta-base <br>
# __Status:__ Version 1.0 <br>
#
# Amir Hossini

# %% [markdown]
# #### Libraries

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import transformers
from transformers import AutoTokenizer
from transformers import TFAutoModelForSequenceClassification
import tensorflow as tf
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.callbacks import Callback
import sklearn
from sklearn.metrics import confusion_matrix,f1_score,precision_score,recall_score 
from tensorflow.keras import backend as K
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' 

print(f"Tensorflow version: {tf.__version__}")
print(f"Sklearn version: {sklearn.__version__}")
print(f"Transformers version: {transformers.__version__}")

physical_devices = tf.config.list_physical_devices('GPU') 
for device in physical_devices:
    tf.config.experimental.set_memory_growth(device, True)
    
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Tensorflow version: 2.5.0
# Sklearn version: 1.0
# Transformers version: 4.11.3
# Num GPUs Available:  1

# %% [markdown]
# #### I/O Files & Params

# %%
fl_train        = '../datasets/banking77/train.csv'
fl_test         = '../datasets/banking77/test.csv'

checkpoint      ='roberta-base'

experiment_grid = {
    'n_labels'  : [3],
    'n_train_inst': [3]
}

seed = 42
BIG_int = 10**21

# %% [markdown]
# #### Functions

# %%
class Metrics(Callback):
    def __init__(self, validation_data):
        super(Metrics, self).__init__()
        self.validation_data = validation_data
        
    def on_epoch_end(self, epoch, logs={}):
        val_predict = np.argmax(tf.nn.softmax(self.model.predict(self.validation_data[0]).logits),1)
        val_targ = self.validation_data[1]
        val_f1 = f1_score(val_targ, val_predict, average='macro')
        val_recall = recall_score(val_targ, val_predict, average='macro')
        val_precision = precision_score(val_targ, val_predict, average='macro')
        logs['val_f1'] = val_f1
        logs['val_recall'] = val_recall
        logs['val_precision'] = val_precision
        print (f'— val_f1: {round(val_f1,4)} — val_precision: {round(val_precision,4)} — val_recall: {round(val_recall,4)}')
        return

def select_data_instances(train, test, col_label, n_labels=None, n_train_inst=None):
    if n_labels is None:
        n_labels = len(train.loc[:,col_label].unique())
    if n_train_inst is None:
        n_train_inst = BIG_int 
        
    select_labels = np.array(train.loc[:,col_label].value_counts()[0:n_labels].index)
    select_train  = train.loc[train[col_label].isin(select_labels),:].reset_index(drop=True)
    subset_train  = pd.DataFrame(columns=select_train.columns)
    for label in select_labels:
        temp_train   = select_train.loc[select_train[col_label]==label,:].reset_index(drop=True)
        select_indx  = np.random.choice(range(len(temp_train)),min(n_train_inst,len(temp_train)))
        temp_train   = temp_train.iloc[select_indx,:]
        subset_train = subset_train.append(temp_train)
    subset_train = subset_train.sample(frac=1).reset_index(drop=True)
    select_test  = test.loc[test[col_label].isin(select_labels),:].reset_index(drop=True)
    select_test  = select_test.sample(frac=1).reset_index(drop=True)
    return subset_train, select_test 

def factorize_data(train, test, col_label,return_keys=False):
    train_labels, levels = pd.factorize(train.loc[:,col_label])
    categs = pd.concat([train.loc[:,col_label],pd.Series(train_labels)],axis=1).groupby(col_label).mean().index
    labels = pd.concat([train.loc[:,col_label],pd.Series(train_labels)],axis=1).groupby(col_label).mean().values.T[0]
    label_keys=dict(zip(categs,labels))
    test_labels = test.loc[:,col_label].map(lambda x: label_keys[x])
    train.loc[:,col_label]=train_labels
    test.loc[:,col_label]=test_labels
    if return_keys:
        return train, test, label_keys
    else:
        return train, test
    
def tokenize_encode_data(train,test,col_text,col_label,checkpoint,
                         truncation_flag=True, padding_flag=True, return_tensors_opt='np'):
    train_sentences = list(train.loc[:,col_text])
    test_sentences  = list(test.loc[:,col_text])
    train_labels    = list(train.loc[:,col_label])
    test_labels     = list(test.loc[:,col_label])
    tokenizer       = AutoTokenizer.from_pretrained(checkpoint)
    train_encodings = tokenizer(train_sentences, truncation=truncation_flag,
                                padding=padding_flag, return_tensors=return_tensors_opt)
    test_encodings  = tokenizer(test_sentences, truncation=truncation_flag,
                                padding=padding_flag, return_tensors=return_tensors_opt)
    return train_encodings.data, train_labels, test_encodings.data, test_labels 

def transformer_model_compile(checkpoint,n_labels,lr=5e-5):
    model = TFAutoModelForSequenceClassification.from_pretrained(checkpoint, num_labels=n_labels)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
                  loss=SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])
    return model

def transformer_model_fit(model, train_encodings, train_labels, test_encodings, test_labels,epochs=10,batch_size=64):
    history = model.fit(train_encodings,np.array(train_labels),epochs=epochs,batch_size=batch_size,
          validation_data=(test_encodings, np.array(test_labels)),callbacks=[Metrics(validation_data)])
    return history, model

def make_plots(df):  
    sns.set_style("whitegrid")
    sns.set(rc={'figure.figsize':(10,6)})
    sns.set_context("talk")
    sns.lineplot(x="sample_size", y="val_f1", hue="num_categ", marker='o', data=df, legend="full")
    plt.show()
    sns.lineplot(hue="sample_size", y="val_f1", x="num_categ", marker='o', data=df, legend="full")

# %%
np.random.seed(seed)
train_orig = pd.read_csv(fl_train)
test_orig  = pd.read_csv(fl_test)

Big_Matrix      = pd.DataFrame(columns=['num_categ','sample_size','val_f1'])

iexp=0
for ilab in experiment_grid['n_labels']:
    compiled_model = transformer_model_compile(checkpoint,ilab)
    for i_ninst in experiment_grid['n_train_inst']:
        iexp+=1
        train, test = select_data_instances(train_orig, test_orig, 'category', ilab, i_ninst)
        train, test = factorize_data(train, test, 'category')
        print(f'\nExperiment {iexp} with {ilab} labels and {i_ninst} instances')
        print(f'\nsize of training dataset: {len(train)}')
        print(f'size of testing dataset: {len(test)}')
        colors = sns.color_palette('pastel')[0:ilab]
        _ = plt.pie(list(train['category'].value_counts()), 
                    labels = list(train['category'].value_counts().index), 
                    colors = colors, autopct='%.0f%%')
        _ = plt.title('Classes')
        _ = plt.show()
        
        train_encodings, train_labels, test_encodings, test_labels = tokenize_encode_data(train,test,'text',
                                                                                          'category',checkpoint)
        validation_data                                            =(test_encodings, np.array(test_labels))
        
        history, fitted_model = transformer_model_fit(compiled_model,train_encodings,train_labels,
                                                      test_encodings, test_labels,epochs=50)

        fig, axes   = plt.subplots(1,3,figsize=(15,5))
        epoch_range = np.arange(1,len(history.history['loss'])+1)
        axes[0]   = sns.lineplot(ax=axes[0],x=epoch_range,y=history.history['loss'],label='Training Loss')
        axes[0]   = sns.lineplot(ax=axes[0],x=epoch_range,y=history.history['val_loss'],label='Validation Loss').set_title('Loss')
        axes[1]   = sns.lineplot(ax=axes[1],x=epoch_range,y=history.history['accuracy'],label='Training Accuracy')
        axes[1]   = sns.lineplot(ax=axes[1],x=epoch_range,y=history.history['val_accuracy'],label='Validation Accuracy').set_title('Accuracy')
        axes[2]   = sns.lineplot(ax=axes[2],x=epoch_range,y=history.history['val_precision'],label='Validation Precision')
        axes[2]   = sns.lineplot(ax=axes[2],x=epoch_range,y=history.history['val_recall'],label='Validation Recall')
        axes[2]   = sns.lineplot(ax=axes[2],x=epoch_range,y=history.history['val_f1'],label='Validation f1_score(macro)').set_title('Precision/Recall/f1_score')
        axes[1].set_ylim=(0, 1)
        axes[2].set_ylim=(0, 1)
        _         = plt.show()
        
        Big_Matrix.loc[iexp,'num_categ']    = ilab
        Big_Matrix.loc[iexp,'sample_size']  = i_ninst
        Big_Matrix.loc[iexp,'val_f1'] = np.max(history.history['val_f1'])
# Out:
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# Some layers of TFRobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Experiment 1 with 3 labels and 3 instances
#
# size of training dataset: 9
# size of testing dataset: 120
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\Windows\anaconda3\envs\tf2.5\lib\site-packages\tensorflow\python\ops\array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# 1/1 [==============================] - 14s 14s/step - loss: 1.0671 - accuracy: 0.4444 - val_loss: 1.0958 - val_accuracy: 0.3333
# — val_f1: 0.1667 — val_precision: 0.1111 — val_recall: 0.3333
# Epoch 2/50
# 1/1 [==============================] - 0s 420ms/step - loss: 1.0950 - accuracy: 0.4444 - val_loss: 1.0925 - val_accuracy: 0.3333
# — val_f1: 0.1667 — val_precision: 0.1111 — val_recall: 0.3333
# Epoch 3/50
# 1/1 [==============================] - 0s 486ms/step - loss: 1.1683 - accuracy: 0.4444 - val_loss: 1.0859 - val_accuracy: 0.5917
# — val_f1: 0.475 — val_precision: 0.4074 — val_recall: 0.5917
# Epoch 4/50
# 1/1 [==============================] - 0s 417ms/step - loss: 1.0646 - accuracy: 0.4444 - val_loss: 1.0743 - val_accuracy: 0.6000
# — val_f1: 0.4993 — val_precision: 0.7519 — val_recall: 0.6
# Epoch 5/50
# 1/1 [==============================] - 0s 407ms/step - loss: 1.0322 - accuracy: 0.7778 - val_loss: 1.0497 - val_accuracy: 0.7667
# — val_f1: 0.763 — val_precision: 0.8135 — val_recall: 0.7667
# Epoch 6/50
# 1/1 [==============================] - 0s 423ms/step - loss: 0.9503 - accuracy: 1.0000 - val_loss: 0.9851 - val_accuracy: 0.8750
# — val_f1: 0.8752 — val_precision: 0.8791 — val_recall: 0.875
# Epoch 7/50
# 1/1 [==============================] - 1s 534ms/step - loss: 0.8587 - accuracy: 1.0000 - val_loss: 0.8814 - val_accuracy: 0.8417
# — val_f1: 0.8427 — val_precision: 0.8598 — val_recall: 0.8417
# Epoch 8/50
# 1/1 [==============================] - 0s 419ms/step - loss: 0.7323 - accuracy: 1.0000 - val_loss: 0.7480 - val_accuracy: 0.9000
# — val_f1: 0.9015 — val_precision: 0.908 — val_recall: 0.9
# Epoch 9/50
# 1/1 [==============================] - 0s 417ms/step - loss: 0.5795 - accuracy: 1.0000 - val_loss: 0.6425 - val_accuracy: 0.8917
# — val_f1: 0.8914 — val_precision: 0.8924 — val_recall: 0.8917
# Epoch 10/50
# 1/1 [==============================] - 0s 432ms/step - loss: 0.3931 - accuracy: 1.0000 - val_loss: 0.5538 - val_accuracy: 0.8917
# — val_f1: 0.8898 — val_precision: 0.8925 — val_recall: 0.8917
# Epoch 11/50
# 1/1 [==============================] - 0s 420ms/step - loss: 0.2495 - accuracy: 1.0000 - val_loss: 0.4828 - val_accuracy: 0.8917
# — val_f1: 0.8888 — val_precision: 0.8935 — val_recall: 0.8917
# Epoch 12/50
# 1/1 [==============================] - 0s 416ms/step - loss: 0.2201 - accuracy: 1.0000 - val_loss: 0.4176 - val_accuracy: 0.8917
# — val_f1: 0.8888 — val_precision: 0.8935 — val_recall: 0.8917
# Epoch 13/50
# 1/1 [==============================] - 0s 428ms/step - loss: 0.1793 - accuracy: 1.0000 - val_loss: 0.3564 - val_accuracy: 0.9000
# — val_f1: 0.8988 — val_precision: 0.9014 — val_recall: 0.9
# Epoch 14/50
# 1/1 [==============================] - 0s 424ms/step - loss: 0.1104 - accuracy: 1.0000 - val_loss: 0.3162 - val_accuracy: 0.9000
# — val_f1: 0.8993 — val_precision: 0.9007 — val_recall: 0.9
# Epoch 15/50
# 1/1 [==============================] - 0s 487ms/step - loss: 0.0828 - accuracy: 1.0000 - val_loss: 0.2909 - val_accuracy: 0.9000
# — val_f1: 0.8996 — val_precision: 0.9027 — val_recall: 0.9
# Epoch 16/50
# 1/1 [==============================] - 0s 418ms/step - loss: 0.0639 - accuracy: 1.0000 - val_loss: 0.2750 - val_accuracy: 0.9000
# — val_f1: 0.8996 — val_precision: 0.9027 — val_recall: 0.9
# Epoch 17/50
# 1/1 [==============================] - 0s 422ms/step - loss: 0.0435 - accuracy: 1.0000 - val_loss: 0.2678 - val_accuracy: 0.9000
# — val_f1: 0.8996 — val_precision: 0.9027 — val_recall: 0.9
# Epoch 18/50
# 1/1 [==============================] - 0s 423ms/step - loss: 0.0381 - accuracy: 1.0000 - val_loss: 0.2673 - val_accuracy: 0.8917
# — val_f1: 0.8911 — val_precision: 0.8952 — val_recall: 0.8917
# Epoch 19/50
# 1/1 [==============================] - 0s 423ms/step - loss: 0.0371 - accuracy: 1.0000 - val_loss: 0.2718 - val_accuracy: 0.9000
# — val_f1: 0.8993 — val_precision: 0.9035 — val_recall: 0.9
# Epoch 20/50
# 1/1 [==============================] - 0s 416ms/step - loss: 0.0243 - accuracy: 1.0000 - val_loss: 0.2797 - val_accuracy: 0.9083
# — val_f1: 0.9074 — val_precision: 0.9122 — val_recall: 0.9083
# Epoch 21/50
# 1/1 [==============================] - 0s 424ms/step - loss: 0.0191 - accuracy: 1.0000 - val_loss: 0.2919 - val_accuracy: 0.9000
# — val_f1: 0.8983 — val_precision: 0.9032 — val_recall: 0.9
# Epoch 22/50
# 1/1 [==============================] - 0s 427ms/step - loss: 0.0192 - accuracy: 1.0000 - val_loss: 0.3063 - val_accuracy: 0.8917
# — val_f1: 0.8895 — val_precision: 0.8963 — val_recall: 0.8917
# Epoch 23/50
# 1/1 [==============================] - 0s 455ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.3220 - val_accuracy: 0.8917
# — val_f1: 0.8895 — val_precision: 0.8963 — val_recall: 0.8917
# Epoch 24/50
# 1/1 [==============================] - 0s 426ms/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 0.3384 - val_accuracy: 0.8833
# — val_f1: 0.8806 — val_precision: 0.8896 — val_recall: 0.8833
# Epoch 25/50
# 1/1 [==============================] - 0s 461ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.3550 - val_accuracy: 0.8917
# — val_f1: 0.8886 — val_precision: 0.9006 — val_recall: 0.8917
# Epoch 26/50
# 1/1 [==============================] - 0s 432ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.3702 - val_accuracy: 0.8833
# — val_f1: 0.8796 — val_precision: 0.8944 — val_recall: 0.8833
# Epoch 27/50
# 1/1 [==============================] - 0s 417ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.3843 - val_accuracy: 0.8833
# — val_f1: 0.8796 — val_precision: 0.8944 — val_recall: 0.8833
# Epoch 28/50
# 1/1 [==============================] - 0s 430ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.3972 - val_accuracy: 0.8667
# — val_f1: 0.8607 — val_precision: 0.8799 — val_recall: 0.8667
# Epoch 29/50
# 1/1 [==============================] - 0s 471ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.4089 - val_accuracy: 0.8667
# — val_f1: 0.8607 — val_precision: 0.8799 — val_recall: 0.8667
# Epoch 30/50
# 1/1 [==============================] - 0s 423ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.4188 - val_accuracy: 0.8667
# — val_f1: 0.8607 — val_precision: 0.8799 — val_recall: 0.8667
# Epoch 31/50
# 1/1 [==============================] - 0s 463ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.4271 - val_accuracy: 0.8667
# — val_f1: 0.8607 — val_precision: 0.8799 — val_recall: 0.8667
# Epoch 32/50
# 1/1 [==============================] - 0s 440ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.4339 - val_accuracy: 0.8667
# — val_f1: 0.8607 — val_precision: 0.8799 — val_recall: 0.8667
# Epoch 33/50
# 1/1 [==============================] - 0s 465ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.4396 - val_accuracy: 0.8750
# — val_f1: 0.8706 — val_precision: 0.8884 — val_recall: 0.875
# Epoch 34/50
# 1/1 [==============================] - 0s 432ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.4437 - val_accuracy: 0.8750
# — val_f1: 0.8706 — val_precision: 0.8884 — val_recall: 0.875
# Epoch 35/50
# 1/1 [==============================] - 0s 432ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.4471 - val_accuracy: 0.8750
# — val_f1: 0.8706 — val_precision: 0.8884 — val_recall: 0.875
# Epoch 36/50
# 1/1 [==============================] - 0s 432ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.4499 - val_accuracy: 0.8750
# — val_f1: 0.8706 — val_precision: 0.8884 — val_recall: 0.875
# Epoch 37/50
# 1/1 [==============================] - 0s 448ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.4515 - val_accuracy: 0.8750
# — val_f1: 0.8706 — val_precision: 0.8884 — val_recall: 0.875
# Epoch 38/50
# 1/1 [==============================] - 0s 428ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.4525 - val_accuracy: 0.8750
# — val_f1: 0.8706 — val_precision: 0.8884 — val_recall: 0.875
# Epoch 39/50
# 1/1 [==============================] - 1s 534ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.4531 - val_accuracy: 0.8750
# — val_f1: 0.8706 — val_precision: 0.8884 — val_recall: 0.875
# Epoch 40/50
# 1/1 [==============================] - 0s 424ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4533 - val_accuracy: 0.8750
# — val_f1: 0.8706 — val_precision: 0.8884 — val_recall: 0.875
# Epoch 41/50
# 1/1 [==============================] - 1s 501ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4532 - val_accuracy: 0.8750
# — val_f1: 0.8706 — val_precision: 0.8884 — val_recall: 0.875
# Epoch 42/50
# 1/1 [==============================] - 0s 470ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.4529 - val_accuracy: 0.8750
# — val_f1: 0.8706 — val_precision: 0.8884 — val_recall: 0.875
# Epoch 43/50
# 1/1 [==============================] - 0s 436ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4522 - val_accuracy: 0.8833
# — val_f1: 0.8796 — val_precision: 0.8944 — val_recall: 0.8833
# Epoch 44/50
# 1/1 [==============================] - 0s 459ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.4513 - val_accuracy: 0.8833
# — val_f1: 0.8796 — val_precision: 0.8944 — val_recall: 0.8833
# Epoch 45/50
# 1/1 [==============================] - 0s 463ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.4505 - val_accuracy: 0.8833
# — val_f1: 0.8796 — val_precision: 0.8944 — val_recall: 0.8833
# Epoch 46/50
# 1/1 [==============================] - 0s 480ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.4498 - val_accuracy: 0.8833
# — val_f1: 0.8796 — val_precision: 0.8944 — val_recall: 0.8833
# Epoch 47/50
# 1/1 [==============================] - 1s 539ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.4491 - val_accuracy: 0.8833
# — val_f1: 0.8796 — val_precision: 0.8944 — val_recall: 0.8833
# Epoch 48/50
# 1/1 [==============================] - 1s 543ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.4488 - val_accuracy: 0.8833
# — val_f1: 0.8796 — val_precision: 0.8944 — val_recall: 0.8833
# Epoch 49/50
# 1/1 [==============================] - 0s 422ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.4486 - val_accuracy: 0.8833
# — val_f1: 0.8796 — val_precision: 0.8944 — val_recall: 0.8833
# Epoch 50/50
# 1/1 [==============================] - 1s 509ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.4488 - val_accuracy: 0.8833
# — val_f1: 0.8796 — val_precision: 0.8944 — val_recall: 0.8833
