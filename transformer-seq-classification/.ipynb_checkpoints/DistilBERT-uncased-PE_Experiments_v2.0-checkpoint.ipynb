# %% [markdown]
# __Project:__ Intent Recognition <br>
# __Sub-prj:__ Parametric Evaluation - _number of labels & data fraction_ <br>
# __Experm:__ Distilbert-base-uncased <br>
# __Status:__ Version 2.0 <br>
#     - Added custom callback function for tracking f1-score <br>
# __Contact:__ Amir Hossini <br>
# __Dev Dat:__ Oct 21, 2021 <br>

# %% [markdown]
# #### Libraries

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import transformers
from transformers import AutoTokenizer
from transformers import TFAutoModelForSequenceClassification
import tensorflow as tf
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.callbacks import Callback
import sklearn
from sklearn.metrics import confusion_matrix,f1_score,precision_score,recall_score 
from tensorflow.keras import backend as K
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' 

print(f"Tensorflow version: {tf.__version__}")
print(f"Sklearn version: {sklearn.__version__}")
print(f"Transformers version: {transformers.__version__}")
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Tensorflow version: 2.5.0
# Sklearn version: 1.0
# Transformers version: 4.11.3
# Num GPUs Available:  1

# %% [markdown]
# #### I/O Files & Params

# %%
fl_train = '../datasets/banking77/train.csv'
fl_test  = '../datasets/banking77/test.csv'

# experiment_grid = {
#     'n_labels'  : [2, 5, 10, 20],
#     'train_frac': [0.1, 0.5, 1.0]
# }

experiment_grid = {
    'n_labels'  : [10],
    'train_frac': [0.1]
}

seed = 42

# %% [markdown]
# #### Functions

# %%
class Metrics(Callback):
    def __init__(self, validation_data):
        super(Metrics, self).__init__()
        self.validation_data = validation_data
        
    def on_train_begin(self, logs={}):
        self.val_f1s = []
        self.val_recalls = []
        self.val_precisions = []
 
    def on_epoch_end(self, epoch, logs={}):
        val_predict = np.argmax(tf.nn.softmax(self.model.predict(self.validation_data[0]).logits),1)
        val_targ = self.validation_data[1]
        val_f1 = f1_score(val_targ, val_predict, average='macro')
        val_recall = recall_score(val_targ, val_predict, average='macro')
        val_precision = precision_score(val_targ, val_predict, average='macro')
        logs['val_f1'] = val_f1
        logs['val_recall'] = val_recall
        logs['val_precision'] = val_precision
        print (f'— val_f1: {round(val_f1,4)} — val_precision: {round(val_precision,4)} — val_recall: {round(val_recall,4)}')
        return

def select_data(train, test, col_label, n_labels=None, train_frac=None):
    if n_labels is None:
        n_labels = len(train.loc[:,col_label].unique())
    if train_frac is None:
        train_frac = 1
        
    select_labels = np.array(train.loc[:,col_label].value_counts()[0:n_labels].index)
    select_train  = train.loc[train[col_label].isin(select_labels),:].reset_index(drop=True)
    n_data_train  = len(select_train)
    n_data_select = int(n_data_train * train_frac)
    indx_select   = np.random.choice(range(n_data_train),n_data_select)
    select_train  = select_train.iloc[indx_select,:]
    select_train  = select_train.reset_index(drop=True)
    select_test   = test.loc[test[col_label].isin(select_labels),:].reset_index(drop=True)
    n_data_test   = len(select_test)
    indx_test     = np.random.choice(range(n_data_test),n_data_test)
    select_test   = select_test.iloc[indx_test,:]
    select_test   = select_test.reset_index(drop=True)
    return select_train, select_test

def factorize_data(train, test, col_label,return_keys=False):
    train_labels, levels = pd.factorize(train.loc[:,col_label])
    categs = pd.concat([train.loc[:,col_label],pd.Series(train_labels)],axis=1).groupby(col_label).mean().index
    labels = pd.concat([train.loc[:,col_label],pd.Series(train_labels)],axis=1).groupby(col_label).mean().values.T[0]
    label_keys=dict(zip(categs,labels))
    test_labels = test.loc[:,col_label].map(lambda x: label_keys[x])
    train.loc[:,col_label]=train_labels
    test.loc[:,col_label]=test_labels
    if return_keys:
        return train, test, label_keys
    else:
        return train, test
    
def tokenize_encode_data(train,test,col_text,col_label,checkpoint='distilbert-base-uncased',
                         truncation_flag=True, padding_flag=True, return_tensors_opt='np'):
    train_sentences = list(train.loc[:,col_text])
    test_sentences  = list(test.loc[:,col_text])
    train_labels    = list(train.loc[:,col_label])
    test_labels     = list(test.loc[:,col_label])
    tokenizer       = AutoTokenizer.from_pretrained(checkpoint)
    train_encodings = tokenizer(train_sentences, truncation=truncation_flag,
                                padding=padding_flag, return_tensors=return_tensors_opt)
    test_encodings  = tokenizer(test_sentences, truncation=truncation_flag,
                                padding=padding_flag, return_tensors=return_tensors_opt)
    return train_encodings.data, train_labels, test_encodings.data, test_labels 

def transformer_model(train_encodings, train_labels, test_encodings, test_labels, 
                      n_labels,verbose=3,lr=5e-5, epochs=10,batch_size=64,
                      checkpoint='distilbert-base-uncased'):
    model = TFAutoModelForSequenceClassification.from_pretrained(checkpoint, num_labels=n_labels)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
                  loss=SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])
    history = model.fit(train_encodings,np.array(train_labels),epochs=epochs,batch_size=batch_size,
          validation_data=(test_encodings, np.array(test_labels)),callbacks=[Metrics(validation_data)])
    return history, model

# %%
np.random.seed(seed)
train_orig = pd.read_csv(fl_train)
test_orig  = pd.read_csv(fl_test)

Big_Matrix      = pd.DataFrame(columns=['experiment','num_categ','sample_size','val_f1'])

iexp=0
for ilab in experiment_grid['n_labels']:
    for ifrac in experiment_grid['train_frac']:
        iexp+=1
        train, test = select_data(train_orig, test_orig, 'category', ilab, ifrac)
        train, test = factorize_data(train, test, 'category')
        print(f'\nExperiment {iexp} with {ilab} labels and sample fraction of {ifrac}')
        print(f'\nsize of training dataset: {len(train)}')
        print(f'size of testing dataset: {len(test)}')
        colors = sns.color_palette('pastel')[0:ilab]
        _ = plt.pie(list(train['category'].value_counts()), 
                    labels = list(train['category'].value_counts().index), 
                    colors = colors, autopct='%.0f%%')
        _ = plt.title('Class imbalance')
        _ = plt.show()
        
        train_encodings, train_labels, test_encodings, test_labels = tokenize_encode_data(train,test,'text','category',checkpoint='distilbert-base-uncased')
        validation_data=(test_encodings, np.array(test_labels))
        history, fitted_model = transformer_model(train_encodings, train_labels, test_encodings, test_labels,ilab,epochs=40)
        fig, axes   = plt.subplots(1,3,figsize=(15,5))
        epoch_range = np.arange(1,len(history.history['loss'])+1)
        axes[0]   = sns.lineplot(ax=axes[0],x=epoch_range,y=history.history['loss'],label='Training Loss')
        axes[0]   = sns.lineplot(ax=axes[0],x=epoch_range,y=history.history['val_loss'],label='Validation Loss').set_title('Loss')
        axes[1]   = sns.lineplot(ax=axes[1],x=epoch_range,y=history.history['accuracy'],label='Training Accuracy')
        axes[1]   = sns.lineplot(ax=axes[1],x=epoch_range,y=history.history['val_accuracy'],label='Validation Accuracy').set_title('Accuracy')
        axes[2]   = sns.lineplot(ax=axes[2],x=epoch_range,y=history.history['val_precision'],label='Validation Precision')
        axes[2]   = sns.lineplot(ax=axes[2],x=epoch_range,y=history.history['val_recall'],label='Validation Recall')
        axes[2]   = sns.lineplot(ax=axes[2],x=epoch_range,y=history.history['val_f1'],label='Validation f1_score(macro)').set_title('Precision/Recall/f1_score')
    
        _         = plt.show()
        
        Big_Matrix['experiment']   = iexp
        Big_Matrix['num_categ']    = ilab
        Big_Matrix['sample_size']  = ifrac
        Big_Matrix['val_f1'] = np.max(history.history['val_f1'])
# Out:
# Experiment 1 with 10 labels and sample fraction of 0.1
#
# size of training dataset: 176
# size of testing dataset: 400
# Some layers from the model checkpoint at distilbert-base-uncased were not used when initializing TFDistilBertForSequenceClassification: ['vocab_transform', 'vocab_layer_norm', 'vocab_projector', 'activation_13']
# - This IS expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some layers of TFDistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier', 'dropout_439', 'classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/40
# 3/3 [==============================] - 7s 1s/step - loss: 2.2969 - accuracy: 0.1193 - val_loss: 2.2698 - val_accuracy: 0.2025
# — val_f1: 0.1277 — val_precision: 0.2019 — val_recall: 0.1946
# Epoch 2/40
# 3/3 [==============================] - 2s 676ms/step - loss: 2.2378 - accuracy: 0.2500 - val_loss: 2.2143 - val_accuracy: 0.2475
# — val_f1: 0.1914 — val_precision: 0.4187 — val_recall: 0.247
# Epoch 3/40
# 3/3 [==============================] - 2s 677ms/step - loss: 2.1281 - accuracy: 0.3750 - val_loss: 2.1202 - val_accuracy: 0.3450
# — val_f1: 0.3005 — val_precision: 0.4793 — val_recall: 0.3526
# Epoch 4/40
# 3/3 [==============================] - 2s 678ms/step - loss: 2.0012 - accuracy: 0.5284 - val_loss: 1.9948 - val_accuracy: 0.4750
# — val_f1: 0.4285 — val_precision: 0.5405 — val_recall: 0.4989
# Epoch 5/40
# 3/3 [==============================] - 2s 680ms/step - loss: 1.8457 - accuracy: 0.6818 - val_loss: 1.8537 - val_accuracy: 0.6050
# — val_f1: 0.5821 — val_precision: 0.7073 — val_recall: 0.617
# Epoch 6/40
# 3/3 [==============================] - 2s 681ms/step - loss: 1.6724 - accuracy: 0.8011 - val_loss: 1.7014 - val_accuracy: 0.6525
# — val_f1: 0.6261 — val_precision: 0.7452 — val_recall: 0.6551
# Epoch 7/40
# 3/3 [==============================] - 2s 704ms/step - loss: 1.4960 - accuracy: 0.8807 - val_loss: 1.5483 - val_accuracy: 0.7275
# — val_f1: 0.7042 — val_precision: 0.7812 — val_recall: 0.7216
# Epoch 8/40
# 3/3 [==============================] - 2s 705ms/step - loss: 1.3188 - accuracy: 0.8977 - val_loss: 1.3916 - val_accuracy: 0.7400
# — val_f1: 0.725 — val_precision: 0.7997 — val_recall: 0.7368
# Epoch 9/40
# 3/3 [==============================] - 2s 684ms/step - loss: 1.1421 - accuracy: 0.9091 - val_loss: 1.2490 - val_accuracy: 0.7825
# — val_f1: 0.7724 — val_precision: 0.8192 — val_recall: 0.7791
# Epoch 10/40
# 3/3 [==============================] - 2s 722ms/step - loss: 0.9799 - accuracy: 0.9659 - val_loss: 1.1120 - val_accuracy: 0.8125
# — val_f1: 0.8045 — val_precision: 0.8413 — val_recall: 0.8071
# Epoch 11/40
# 3/3 [==============================] - 2s 734ms/step - loss: 0.8227 - accuracy: 0.9830 - val_loss: 0.9939 - val_accuracy: 0.8075
# — val_f1: 0.7971 — val_precision: 0.8284 — val_recall: 0.8016
# Epoch 12/40
# 3/3 [==============================] - 2s 688ms/step - loss: 0.6834 - accuracy: 1.0000 - val_loss: 0.8801 - val_accuracy: 0.8475
# — val_f1: 0.8428 — val_precision: 0.8577 — val_recall: 0.8448
# Epoch 13/40
# 3/3 [==============================] - 2s 687ms/step - loss: 0.5597 - accuracy: 1.0000 - val_loss: 0.7799 - val_accuracy: 0.8450
# — val_f1: 0.8415 — val_precision: 0.8549 — val_recall: 0.8417
# Epoch 14/40
# 3/3 [==============================] - 2s 685ms/step - loss: 0.4552 - accuracy: 1.0000 - val_loss: 0.7201 - val_accuracy: 0.8375
# — val_f1: 0.8312 — val_precision: 0.8475 — val_recall: 0.8328
# Epoch 15/40
# 3/3 [==============================] - 2s 678ms/step - loss: 0.3749 - accuracy: 1.0000 - val_loss: 0.6588 - val_accuracy: 0.8500
# — val_f1: 0.8465 — val_precision: 0.8562 — val_recall: 0.8488
# Epoch 16/40
# 3/3 [==============================] - 2s 687ms/step - loss: 0.3051 - accuracy: 1.0000 - val_loss: 0.6000 - val_accuracy: 0.8725
# — val_f1: 0.8715 — val_precision: 0.8784 — val_recall: 0.8707
# Epoch 17/40
# 3/3 [==============================] - 2s 703ms/step - loss: 0.2559 - accuracy: 1.0000 - val_loss: 0.5581 - val_accuracy: 0.8725
# — val_f1: 0.8705 — val_precision: 0.8762 — val_recall: 0.8704
# Epoch 18/40
# 3/3 [==============================] - 2s 690ms/step - loss: 0.2122 - accuracy: 1.0000 - val_loss: 0.5337 - val_accuracy: 0.8575
# — val_f1: 0.8553 — val_precision: 0.864 — val_recall: 0.8554
# Epoch 19/40
# 3/3 [==============================] - 2s 692ms/step - loss: 0.1790 - accuracy: 1.0000 - val_loss: 0.5089 - val_accuracy: 0.8600
# — val_f1: 0.858 — val_precision: 0.8652 — val_recall: 0.8594
# Epoch 20/40
# 3/3 [==============================] - 2s 694ms/step - loss: 0.1534 - accuracy: 1.0000 - val_loss: 0.4915 - val_accuracy: 0.8725
# — val_f1: 0.8717 — val_precision: 0.8794 — val_recall: 0.8706
# Epoch 21/40
# 3/3 [==============================] - 2s 689ms/step - loss: 0.1350 - accuracy: 1.0000 - val_loss: 0.4767 - val_accuracy: 0.8800
# — val_f1: 0.8787 — val_precision: 0.8852 — val_recall: 0.8776
# Epoch 22/40
# 3/3 [==============================] - 2s 685ms/step - loss: 0.1164 - accuracy: 1.0000 - val_loss: 0.4613 - val_accuracy: 0.8725
# — val_f1: 0.8719 — val_precision: 0.8784 — val_recall: 0.8713
# Epoch 23/40
# 3/3 [==============================] - 2s 683ms/step - loss: 0.1056 - accuracy: 1.0000 - val_loss: 0.4529 - val_accuracy: 0.8700
# — val_f1: 0.8681 — val_precision: 0.8763 — val_recall: 0.867
# Epoch 24/40
# 3/3 [==============================] - 2s 715ms/step - loss: 0.0938 - accuracy: 1.0000 - val_loss: 0.4479 - val_accuracy: 0.8700
# — val_f1: 0.8684 — val_precision: 0.8773 — val_recall: 0.867
# Epoch 25/40
# 3/3 [==============================] - 2s 680ms/step - loss: 0.0828 - accuracy: 1.0000 - val_loss: 0.4431 - val_accuracy: 0.8750
# — val_f1: 0.8748 — val_precision: 0.8836 — val_recall: 0.8735
# Epoch 26/40
# 3/3 [==============================] - 2s 703ms/step - loss: 0.0732 - accuracy: 1.0000 - val_loss: 0.4326 - val_accuracy: 0.8850
# — val_f1: 0.8846 — val_precision: 0.8919 — val_recall: 0.883
# Epoch 27/40
# 3/3 [==============================] - 2s 684ms/step - loss: 0.0688 - accuracy: 1.0000 - val_loss: 0.4220 - val_accuracy: 0.8850
# — val_f1: 0.8846 — val_precision: 0.8919 — val_recall: 0.883
# Epoch 28/40
# 3/3 [==============================] - 2s 711ms/step - loss: 0.0640 - accuracy: 1.0000 - val_loss: 0.4193 - val_accuracy: 0.8825
# — val_f1: 0.8826 — val_precision: 0.8907 — val_recall: 0.8809
# Epoch 29/40
# 3/3 [==============================] - 2s 690ms/step - loss: 0.0575 - accuracy: 1.0000 - val_loss: 0.4233 - val_accuracy: 0.8850
# — val_f1: 0.8852 — val_precision: 0.8938 — val_recall: 0.8833
# Epoch 30/40
# 3/3 [==============================] - 2s 694ms/step - loss: 0.0540 - accuracy: 1.0000 - val_loss: 0.4270 - val_accuracy: 0.8825
# — val_f1: 0.8831 — val_precision: 0.8916 — val_recall: 0.8815
# Epoch 31/40
# 3/3 [==============================] - 2s 724ms/step - loss: 0.0500 - accuracy: 1.0000 - val_loss: 0.4256 - val_accuracy: 0.8800
# — val_f1: 0.8801 — val_precision: 0.8895 — val_recall: 0.8782
# Epoch 32/40
# 3/3 [==============================] - 2s 710ms/step - loss: 0.0475 - accuracy: 1.0000 - val_loss: 0.4205 - val_accuracy: 0.8750
# — val_f1: 0.8742 — val_precision: 0.8825 — val_recall: 0.8726
# Epoch 33/40
# 3/3 [==============================] - 2s 692ms/step - loss: 0.0444 - accuracy: 1.0000 - val_loss: 0.4180 - val_accuracy: 0.8750
# — val_f1: 0.8742 — val_precision: 0.8825 — val_recall: 0.8726
# Epoch 34/40
# 3/3 [==============================] - 2s 694ms/step - loss: 0.0418 - accuracy: 1.0000 - val_loss: 0.4198 - val_accuracy: 0.8775
# — val_f1: 0.8768 — val_precision: 0.8853 — val_recall: 0.875
# Epoch 35/40
# 3/3 [==============================] - 2s 720ms/step - loss: 0.0390 - accuracy: 1.0000 - val_loss: 0.4216 - val_accuracy: 0.8775
# — val_f1: 0.8768 — val_precision: 0.8853 — val_recall: 0.875
# Epoch 36/40
# 3/3 [==============================] - 2s 694ms/step - loss: 0.0360 - accuracy: 1.0000 - val_loss: 0.4209 - val_accuracy: 0.8800
# — val_f1: 0.8789 — val_precision: 0.8876 — val_recall: 0.8768
# Epoch 37/40
# 3/3 [==============================] - 2s 700ms/step - loss: 0.0348 - accuracy: 1.0000 - val_loss: 0.4177 - val_accuracy: 0.8800
# — val_f1: 0.8789 — val_precision: 0.8876 — val_recall: 0.8768
# Epoch 38/40
# 3/3 [==============================] - 2s 706ms/step - loss: 0.0330 - accuracy: 1.0000 - val_loss: 0.4156 - val_accuracy: 0.8800
# — val_f1: 0.8789 — val_precision: 0.8876 — val_recall: 0.8768
# Epoch 39/40
# 3/3 [==============================] - 2s 693ms/step - loss: 0.0316 - accuracy: 1.0000 - val_loss: 0.4165 - val_accuracy: 0.8800
# — val_f1: 0.8789 — val_precision: 0.8876 — val_recall: 0.8768
# Epoch 40/40
# 3/3 [==============================] - 2s 689ms/step - loss: 0.0304 - accuracy: 1.0000 - val_loss: 0.4183 - val_accuracy: 0.8800
# — val_f1: 0.8789 — val_precision: 0.8876 — val_recall: 0.8768
