# %% [markdown]
# ## How to quantify F1-Score when fine-tuning pre-trained transformers for NLP tasks?
#
# #### Example

# %% [markdown]
# #### Libraries

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import transformers
from transformers import AutoTokenizer
from transformers import TFAutoModelForSequenceClassification
import tensorflow as tf
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.callbacks import Callback
import sklearn
from sklearn.metrics import confusion_matrix,f1_score,precision_score,recall_score 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

print(f"Tensorflow version: {tf.__version__}")
print(f"Sklearn version: {sklearn.__version__}")
print(f"Transformers version: {transformers.__version__}")

physical_devices = tf.config.list_physical_devices('GPU') 
for device in physical_devices:
    tf.config.experimental.set_memory_growth(device, True)
    
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Tensorflow version: 2.5.0
# Sklearn version: 1.0
# Transformers version: 4.11.3
# Num GPUs Available:  1

# %% [markdown]
# #### I/O Files & Params

# %%
fl_train        = '../datasets/banking77/train.csv'
fl_test         = '../datasets/banking77/test.csv'

checkpoint      ='distilbert-base-uncased'

experiment_grid = {
    'n_labels'  : [5],
    'n_train_inst': [5]
}

seed = 0
BIG_int = 10**21
n_epochs = 50

# %% [markdown]
# #### Functions

# %%
class Metrics(Callback):
    def __init__(self, validation_data):
        super(Metrics, self).__init__()
        self.validation_data = validation_data
        
    def on_train_begin(self, logs={}):
        self.val_f1s = []
        self.val_recalls = []
        self.val_precisions = []
 
    def on_epoch_end(self, epoch, logs={}):
        val_predict = np.argmax(tf.nn.softmax(self.model.predict(self.validation_data[0]).logits),1)
        val_targ = self.validation_data[1]
        val_f1 = f1_score(val_targ, val_predict, average='macro')
        val_recall = recall_score(val_targ, val_predict, average='macro')
        val_precision = precision_score(val_targ, val_predict, average='macro')
        logs['val_f1'] = val_f1
        logs['val_recall'] = val_recall
        logs['val_precision'] = val_precision
        print (f'— val_f1: {round(val_f1,4)} — val_precision: {round(val_precision,4)} — val_recall: {round(val_recall,4)}')
        return

def select_data_instances(train, test, col_label, n_labels=None, n_train_inst=None):
    if n_labels is None:
        n_labels = len(train.loc[:,col_label].unique())
    if n_train_inst is None:
        n_train_inst = BIG_int 
        
    select_labels = np.array(train.loc[:,col_label].value_counts()[0:n_labels].index)
    select_train  = train.loc[train[col_label].isin(select_labels),:].reset_index(drop=True)
    subset_train  = pd.DataFrame(columns=select_train.columns)
    for label in select_labels:
        temp_train   = select_train.loc[select_train[col_label]==label,:].reset_index(drop=True)
        select_indx  = np.random.choice(range(len(temp_train)),min(n_train_inst,len(temp_train)))
        temp_train   = temp_train.iloc[select_indx,:]
        subset_train = subset_train.append(temp_train)
    subset_train = subset_train.sample(frac=1).reset_index(drop=True)
    select_test  = test.loc[test[col_label].isin(select_labels),:].reset_index(drop=True)
    select_test  = select_test.sample(frac=1).reset_index(drop=True)
    return subset_train, select_test 

def factorize_data(train, test, col_label,return_keys=False):
    train_labels, levels = pd.factorize(train.loc[:,col_label])
    categs = pd.concat([train.loc[:,col_label],pd.Series(train_labels)],axis=1).groupby(col_label).mean().index
    labels = pd.concat([train.loc[:,col_label],pd.Series(train_labels)],axis=1).groupby(col_label).mean().values.T[0]
    label_keys=dict(zip(categs,labels))
    test_labels = test.loc[:,col_label].map(lambda x: label_keys[x])
    train.loc[:,col_label]=train_labels
    test.loc[:,col_label]=test_labels
    if return_keys:
        return train, test, label_keys
    else:
        return train, test
    
def tokenize_encode_data(train,test,col_text,col_label,checkpoint,
                         truncation_flag=True, padding_flag=True, return_tensors_opt='np'):
    train_sentences = list(train.loc[:,col_text])
    test_sentences  = list(test.loc[:,col_text])
    train_labels    = list(train.loc[:,col_label])
    test_labels     = list(test.loc[:,col_label])
    tokenizer       = AutoTokenizer.from_pretrained(checkpoint)
    train_encodings = tokenizer(train_sentences, truncation=truncation_flag,
                                padding=padding_flag, return_tensors=return_tensors_opt)
    test_encodings  = tokenizer(test_sentences, truncation=truncation_flag,
                                padding=padding_flag, return_tensors=return_tensors_opt)
    return train_encodings.data, train_labels, test_encodings.data, test_labels 

def transformer_model_compile(checkpoint,n_labels,lr=5e-5):
    model = TFAutoModelForSequenceClassification.from_pretrained(checkpoint, num_labels=n_labels)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
                  loss=SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])
    return model

def transformer_model_fit(model, train_encodings, train_labels, test_encodings, test_labels,epochs=10,batch_size=64):
    history = model.fit(train_encodings,np.array(train_labels),epochs=epochs,batch_size=batch_size,
          validation_data=(test_encodings, np.array(test_labels)),callbacks=[Metrics(validation_data)])
    return history, model

# %%
np.random.seed(seed)
train_orig = pd.read_csv(fl_train)
test_orig  = pd.read_csv(fl_test)

iexp=0
for ilab in experiment_grid['n_labels']:
    compiled_model = transformer_model_compile(checkpoint,ilab)
    for i_ninst in experiment_grid['n_train_inst']:
        iexp+=1
        train, test = select_data_instances(train_orig, test_orig, 'category', ilab, i_ninst)
        train, test = factorize_data(train, test, 'category')
        
        train_encodings, train_labels, test_encodings, test_labels = tokenize_encode_data(train,test,'text',
                                                                                          'category',checkpoint)
        validation_data                                            =(test_encodings, np.array(test_labels))
        
        history, fitted_model = transformer_model_fit(compiled_model,train_encodings,train_labels,
                                                      test_encodings, test_labels,epochs=n_epochs)

        fig, axes   = plt.subplots(1,3,figsize=(15,5))
        epoch_range = np.arange(1,len(history.history['loss'])+1)
        axes[0]   = sns.lineplot(ax=axes[0],x=epoch_range,y=history.history['loss'],label='Training Loss')
        axes[0]   = sns.lineplot(ax=axes[0],x=epoch_range,y=history.history['val_loss'],label='Validation Loss').set_title('Loss')
        axes[1]   = sns.lineplot(ax=axes[1],x=epoch_range,y=history.history['accuracy'],label='Training Accuracy')
        axes[1]   = sns.lineplot(ax=axes[1],x=epoch_range,y=history.history['val_accuracy'],label='Validation Accuracy').set_title('Accuracy')
        axes[2]   = sns.lineplot(ax=axes[2],x=epoch_range,y=history.history['val_precision'],label='Validation Precision')
        axes[2]   = sns.lineplot(ax=axes[2],x=epoch_range,y=history.history['val_recall'],label='Validation Recall')
        axes[2]   = sns.lineplot(ax=axes[2],x=epoch_range,y=history.history['val_f1'],label='Validation f1_score(macro)').set_title('Precision/Recall/f1_score')
        axes[1].set_ylim=(0, 1)
        axes[2].set_ylim=(0, 1)
        _         = plt.show()
# Out:
# Some layers from the model checkpoint at distilbert-base-uncased were not used when initializing TFDistilBertForSequenceClassification: ['vocab_projector', 'vocab_layer_norm', 'activation_13', 'vocab_transform']
# - This IS expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some layers of TFDistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier', 'classifier', 'dropout_157']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/50
# 1/1 [==============================] - 6s 6s/step - loss: 1.6213 - accuracy: 0.2000 - val_loss: 1.6045 - val_accuracy: 0.3150
# — val_f1: 0.2365 — val_precision: 0.1902 — val_recall: 0.315
# Epoch 2/50
# 1/1 [==============================] - 0s 476ms/step - loss: 1.6013 - accuracy: 0.2000 - val_loss: 1.5965 - val_accuracy: 0.3750
# — val_f1: 0.307 — val_precision: 0.4408 — val_recall: 0.375
# Epoch 3/50
# 1/1 [==============================] - 0s 479ms/step - loss: 1.5702 - accuracy: 0.5600 - val_loss: 1.5847 - val_accuracy: 0.5300
# — val_f1: 0.5275 — val_precision: 0.6482 — val_recall: 0.53
# Epoch 4/50
# 1/1 [==============================] - 0s 474ms/step - loss: 1.5585 - accuracy: 0.7200 - val_loss: 1.5674 - val_accuracy: 0.5750
# — val_f1: 0.574 — val_precision: 0.6517 — val_recall: 0.575
# Epoch 5/50
# 1/1 [==============================] - 0s 475ms/step - loss: 1.5170 - accuracy: 0.7600 - val_loss: 1.5443 - val_accuracy: 0.5650
# — val_f1: 0.5649 — val_precision: 0.6426 — val_recall: 0.565
# Epoch 6/50
# 1/1 [==============================] - 0s 480ms/step - loss: 1.4538 - accuracy: 0.9200 - val_loss: 1.5154 - val_accuracy: 0.5850
# — val_f1: 0.59 — val_precision: 0.6624 — val_recall: 0.585
# Epoch 7/50
# 1/1 [==============================] - 0s 472ms/step - loss: 1.4112 - accuracy: 0.9600 - val_loss: 1.4805 - val_accuracy: 0.5900
# — val_f1: 0.5966 — val_precision: 0.6657 — val_recall: 0.59
# Epoch 8/50
# 1/1 [==============================] - 0s 479ms/step - loss: 1.3407 - accuracy: 0.9600 - val_loss: 1.4386 - val_accuracy: 0.6150
# — val_f1: 0.6228 — val_precision: 0.6833 — val_recall: 0.615
# Epoch 9/50
# 1/1 [==============================] - 0s 478ms/step - loss: 1.2520 - accuracy: 1.0000 - val_loss: 1.3887 - val_accuracy: 0.6300
# — val_f1: 0.6388 — val_precision: 0.6908 — val_recall: 0.63
# Epoch 10/50
# 1/1 [==============================] - 0s 478ms/step - loss: 1.1587 - accuracy: 1.0000 - val_loss: 1.3355 - val_accuracy: 0.6550
# — val_f1: 0.6627 — val_precision: 0.6959 — val_recall: 0.655
# Epoch 11/50
# 1/1 [==============================] - 0s 479ms/step - loss: 1.0762 - accuracy: 1.0000 - val_loss: 1.2839 - val_accuracy: 0.6700
# — val_f1: 0.676 — val_precision: 0.6998 — val_recall: 0.67
# Epoch 12/50
# 1/1 [==============================] - 0s 479ms/step - loss: 1.0021 - accuracy: 1.0000 - val_loss: 1.2307 - val_accuracy: 0.6900
# — val_f1: 0.6939 — val_precision: 0.716 — val_recall: 0.69
# Epoch 13/50
# 1/1 [==============================] - 0s 479ms/step - loss: 0.9146 - accuracy: 1.0000 - val_loss: 1.1794 - val_accuracy: 0.6950
# — val_f1: 0.6982 — val_precision: 0.7189 — val_recall: 0.695
# Epoch 14/50
# 1/1 [==============================] - 1s 516ms/step - loss: 0.8292 - accuracy: 1.0000 - val_loss: 1.1325 - val_accuracy: 0.6900
# — val_f1: 0.6917 — val_precision: 0.713 — val_recall: 0.69
# Epoch 15/50
# 1/1 [==============================] - 1s 513ms/step - loss: 0.7611 - accuracy: 1.0000 - val_loss: 1.0872 - val_accuracy: 0.6950
# — val_f1: 0.6933 — val_precision: 0.7166 — val_recall: 0.695
# Epoch 16/50
# 1/1 [==============================] - 0s 480ms/step - loss: 0.6999 - accuracy: 1.0000 - val_loss: 1.0446 - val_accuracy: 0.6950
# — val_f1: 0.6936 — val_precision: 0.7145 — val_recall: 0.695
# Epoch 17/50
# 1/1 [==============================] - 0s 486ms/step - loss: 0.6142 - accuracy: 1.0000 - val_loss: 1.0064 - val_accuracy: 0.7100
# — val_f1: 0.7061 — val_precision: 0.7295 — val_recall: 0.71
# Epoch 18/50
# 1/1 [==============================] - 0s 477ms/step - loss: 0.5493 - accuracy: 1.0000 - val_loss: 0.9668 - val_accuracy: 0.7250
# — val_f1: 0.7212 — val_precision: 0.7429 — val_recall: 0.725
# Epoch 19/50
# 1/1 [==============================] - 0s 481ms/step - loss: 0.4953 - accuracy: 1.0000 - val_loss: 0.9260 - val_accuracy: 0.7350
# — val_f1: 0.7335 — val_precision: 0.7521 — val_recall: 0.735
# Epoch 20/50
# 1/1 [==============================] - 0s 482ms/step - loss: 0.4355 - accuracy: 1.0000 - val_loss: 0.8898 - val_accuracy: 0.7400
# — val_f1: 0.7414 — val_precision: 0.7614 — val_recall: 0.74
# Epoch 21/50
# 1/1 [==============================] - 0s 481ms/step - loss: 0.4044 - accuracy: 1.0000 - val_loss: 0.8574 - val_accuracy: 0.7400
# — val_f1: 0.7422 — val_precision: 0.7638 — val_recall: 0.74
# Epoch 22/50
# 1/1 [==============================] - 0s 484ms/step - loss: 0.3707 - accuracy: 1.0000 - val_loss: 0.8266 - val_accuracy: 0.7350
# — val_f1: 0.7368 — val_precision: 0.7593 — val_recall: 0.735
# Epoch 23/50
# 1/1 [==============================] - 0s 476ms/step - loss: 0.3319 - accuracy: 1.0000 - val_loss: 0.7955 - val_accuracy: 0.7500
# — val_f1: 0.7503 — val_precision: 0.771 — val_recall: 0.75
# Epoch 24/50
# 1/1 [==============================] - 0s 479ms/step - loss: 0.3002 - accuracy: 1.0000 - val_loss: 0.7666 - val_accuracy: 0.7650
# — val_f1: 0.7649 — val_precision: 0.7869 — val_recall: 0.765
# Epoch 25/50
# 1/1 [==============================] - 0s 483ms/step - loss: 0.2729 - accuracy: 1.0000 - val_loss: 0.7417 - val_accuracy: 0.7700
# — val_f1: 0.7702 — val_precision: 0.788 — val_recall: 0.77
# Epoch 26/50
# 1/1 [==============================] - 0s 483ms/step - loss: 0.2322 - accuracy: 1.0000 - val_loss: 0.7200 - val_accuracy: 0.7700
# — val_f1: 0.7702 — val_precision: 0.788 — val_recall: 0.77
# Epoch 27/50
# 1/1 [==============================] - 0s 481ms/step - loss: 0.2169 - accuracy: 1.0000 - val_loss: 0.7038 - val_accuracy: 0.7650
# — val_f1: 0.7652 — val_precision: 0.7818 — val_recall: 0.765
# Epoch 28/50
# 1/1 [==============================] - 0s 487ms/step - loss: 0.2026 - accuracy: 1.0000 - val_loss: 0.6906 - val_accuracy: 0.7700
# — val_f1: 0.7698 — val_precision: 0.7834 — val_recall: 0.77
# Epoch 29/50
# 1/1 [==============================] - 1s 564ms/step - loss: 0.1902 - accuracy: 1.0000 - val_loss: 0.6801 - val_accuracy: 0.7700
# — val_f1: 0.7714 — val_precision: 0.7863 — val_recall: 0.77
# Epoch 30/50
# 1/1 [==============================] - 1s 549ms/step - loss: 0.1726 - accuracy: 1.0000 - val_loss: 0.6718 - val_accuracy: 0.7700
# — val_f1: 0.7724 — val_precision: 0.7902 — val_recall: 0.77
# Epoch 31/50
# 1/1 [==============================] - 0s 484ms/step - loss: 0.1446 - accuracy: 1.0000 - val_loss: 0.6635 - val_accuracy: 0.7650
# — val_f1: 0.7679 — val_precision: 0.7863 — val_recall: 0.765
# Epoch 32/50
# 1/1 [==============================] - 0s 482ms/step - loss: 0.1426 - accuracy: 1.0000 - val_loss: 0.6556 - val_accuracy: 0.7550
# — val_f1: 0.758 — val_precision: 0.7792 — val_recall: 0.755
# Epoch 33/50
# 1/1 [==============================] - 0s 488ms/step - loss: 0.1298 - accuracy: 1.0000 - val_loss: 0.6492 - val_accuracy: 0.7550
# — val_f1: 0.7586 — val_precision: 0.7802 — val_recall: 0.755
# Epoch 34/50
# 1/1 [==============================] - 0s 480ms/step - loss: 0.1216 - accuracy: 1.0000 - val_loss: 0.6438 - val_accuracy: 0.7500
# — val_f1: 0.7541 — val_precision: 0.7771 — val_recall: 0.75
# Epoch 35/50
# 1/1 [==============================] - 0s 485ms/step - loss: 0.1161 - accuracy: 1.0000 - val_loss: 0.6395 - val_accuracy: 0.7500
# — val_f1: 0.754 — val_precision: 0.7747 — val_recall: 0.75
# Epoch 36/50
# 1/1 [==============================] - 0s 483ms/step - loss: 0.0985 - accuracy: 1.0000 - val_loss: 0.6338 - val_accuracy: 0.7500
# — val_f1: 0.755 — val_precision: 0.7757 — val_recall: 0.75
# Epoch 37/50
# 1/1 [==============================] - 0s 480ms/step - loss: 0.0958 - accuracy: 1.0000 - val_loss: 0.6296 - val_accuracy: 0.7500
# — val_f1: 0.755 — val_precision: 0.7757 — val_recall: 0.75
# Epoch 38/50
# 1/1 [==============================] - 1s 575ms/step - loss: 0.0891 - accuracy: 1.0000 - val_loss: 0.6256 - val_accuracy: 0.7550
# — val_f1: 0.7594 — val_precision: 0.7788 — val_recall: 0.755
# Epoch 39/50
# 1/1 [==============================] - 1s 505ms/step - loss: 0.0832 - accuracy: 1.0000 - val_loss: 0.6218 - val_accuracy: 0.7600
# — val_f1: 0.7643 — val_precision: 0.7821 — val_recall: 0.76
# Epoch 40/50
# 1/1 [==============================] - 0s 483ms/step - loss: 0.0810 - accuracy: 1.0000 - val_loss: 0.6169 - val_accuracy: 0.7700
# — val_f1: 0.7735 — val_precision: 0.7905 — val_recall: 0.77
# Epoch 41/50
# 1/1 [==============================] - 0s 482ms/step - loss: 0.0712 - accuracy: 1.0000 - val_loss: 0.6132 - val_accuracy: 0.7700
# — val_f1: 0.7735 — val_precision: 0.7905 — val_recall: 0.77
# Epoch 42/50
# 1/1 [==============================] - 0s 488ms/step - loss: 0.0712 - accuracy: 1.0000 - val_loss: 0.6097 - val_accuracy: 0.7750
# — val_f1: 0.7783 — val_precision: 0.7944 — val_recall: 0.775
# Epoch 43/50
# 1/1 [==============================] - 0s 486ms/step - loss: 0.0643 - accuracy: 1.0000 - val_loss: 0.6076 - val_accuracy: 0.7750
# — val_f1: 0.7783 — val_precision: 0.7944 — val_recall: 0.775
# Epoch 44/50
# 1/1 [==============================] - 0s 485ms/step - loss: 0.0628 - accuracy: 1.0000 - val_loss: 0.6068 - val_accuracy: 0.7750
# — val_f1: 0.7783 — val_precision: 0.7944 — val_recall: 0.775
# Epoch 45/50
# 1/1 [==============================] - 0s 484ms/step - loss: 0.0596 - accuracy: 1.0000 - val_loss: 0.6067 - val_accuracy: 0.7750
# — val_f1: 0.7783 — val_precision: 0.7944 — val_recall: 0.775
# Epoch 46/50
# 1/1 [==============================] - 1s 594ms/step - loss: 0.0539 - accuracy: 1.0000 - val_loss: 0.6070 - val_accuracy: 0.7750
# — val_f1: 0.7783 — val_precision: 0.7944 — val_recall: 0.775
# Epoch 47/50
# 1/1 [==============================] - 1s 597ms/step - loss: 0.0529 - accuracy: 1.0000 - val_loss: 0.6073 - val_accuracy: 0.7750
# — val_f1: 0.7783 — val_precision: 0.7944 — val_recall: 0.775
# Epoch 48/50
# 1/1 [==============================] - 0s 484ms/step - loss: 0.0534 - accuracy: 1.0000 - val_loss: 0.6080 - val_accuracy: 0.7750
# — val_f1: 0.7783 — val_precision: 0.7944 — val_recall: 0.775
# Epoch 49/50
# 1/1 [==============================] - 0s 481ms/step - loss: 0.0498 - accuracy: 1.0000 - val_loss: 0.6091 - val_accuracy: 0.7750
# — val_f1: 0.7783 — val_precision: 0.7944 — val_recall: 0.775
# Epoch 50/50
# 1/1 [==============================] - 0s 486ms/step - loss: 0.0467 - accuracy: 1.0000 - val_loss: 0.6100 - val_accuracy: 0.7800
# — val_f1: 0.7836 — val_precision: 0.8002 — val_recall: 0.78
