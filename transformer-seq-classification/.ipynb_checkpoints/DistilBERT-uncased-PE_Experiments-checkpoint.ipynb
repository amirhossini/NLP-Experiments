# %% [markdown]
# __Project:__ Intent Recognition <br>
# __Sub-prj:__ Parametric Evaluation - _number of labels & data fraction_ <br>
# __Experm:__  Distilbert-base-uncased <br>
# __Contact:__ Amir Hossini <br>
# __Dev Dat:__ Oct 13, 2021 <br>

# %% [markdown]
# #### Libraries

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import transformers
from transformers import AutoTokenizer
from transformers import TFAutoModelForSequenceClassification
import tensorflow as tf
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras import backend as K
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' 


print(f"Tensorflow version: {tf.__version__}")
print(f"Transformers version: {transformers.__version__}")
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Tensorflow version: 2.5.0
# Transformers version: 4.11.3
# Num GPUs Available:  1

# %% [markdown]
# #### I/O Files & Params

# %%
fl_train = '../datasets/banking77/train.csv'
fl_test  = '../datasets/banking77/test.csv'

experiment_grid = {
    'n_labels'  : [2, 5, 10, 20],
    'train_frac': [0.1, 0.5, 1.0]
}

seed = 42

# %% [markdown]
# #### Functions

# %%
def select_data(train, test, col_label, n_labels=None, train_frac=None):
    if n_labels is None:
        n_labels = len(train.loc[:,col_label].unique())
    if train_frac is None:
        train_frac = 1
        
    select_labels = np.array(train.loc[:,col_label].value_counts()[0:n_labels].index)
    select_train  = train.loc[train[col_label].isin(select_labels),:].reset_index(drop=True)
    n_data_train  = len(select_train)
    n_data_select = int(n_data_train * train_frac)
    indx_select   = np.random.choice(range(n_data_train),n_data_select)
    select_train  = select_train.iloc[indx_select,:]
    select_train  = select_train.reset_index(drop=True)
    select_test   = test.loc[test[col_label].isin(select_labels),:].reset_index(drop=True)
    n_data_test   = len(select_test)
    indx_test     = np.random.choice(range(n_data_test),n_data_test)
    select_test   = select_test.iloc[indx_test,:]
    select_test   = select_test.reset_index(drop=True)
    return select_train, select_test

def factorize_data(train, test, col_label,return_keys=False):
    train_labels, levels = pd.factorize(train.loc[:,col_label])
    categs = pd.concat([train.loc[:,col_label],pd.Series(train_labels)],axis=1).groupby(col_label).mean().index
    labels = pd.concat([train.loc[:,col_label],pd.Series(train_labels)],axis=1).groupby(col_label).mean().values.T[0]
    label_keys=dict(zip(categs,labels))
    test_labels = test.loc[:,col_label].map(lambda x: label_keys[x])
    train.loc[:,col_label]=train_labels
    test.loc[:,col_label]=test_labels
    if return_keys:
        return train, test, label_keys
    else:
        return train, test
    
def tokenize_encode_data(train,test,col_text,col_label,checkpoint='distilbert-base-uncased',
                         truncation_flag=True, padding_flag=True, return_tensors_opt='tf'):
    train_sentences = list(train.loc[:,col_text])
    test_sentences  = list(test.loc[:,col_text])
    train_labels    = list(train.loc[:,col_label])
    test_labels     = list(test.loc[:,col_label])
    tokenizer       = AutoTokenizer.from_pretrained(checkpoint)
    train_encodings = tokenizer(train_sentences, truncation=truncation_flag,
                                padding=padding_flag, return_tensors=return_tensors_opt)
    test_encodings  = tokenizer(test_sentences, truncation=truncation_flag,
                                padding=padding_flag, return_tensors=return_tensors_opt)
    train_dataset   = tf.data.Dataset.from_tensor_slices((dict(train_encodings),train_labels))
    test_dataset    = tf.data.Dataset.from_tensor_slices((dict(test_encodings),test_labels))
    return train_dataset, test_dataset 

def transformer_model(train_dataset,test_dataset,n_labels,verbose=3,lr=5e-5,
                      epochs=10,batch_size=64,checkpoint='distilbert-base-uncased'):
    model = TFAutoModelForSequenceClassification.from_pretrained(checkpoint, num_labels=n_labels)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
                  loss=SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])
    history = model.fit(train_dataset.batch(batch_size),epochs=epochs,batch_size=batch_size,
          validation_data=test_dataset.batch(batch_size))
    return history, model

# %%
np.random.seed(seed)
train_orig = pd.read_csv(fl_train)
test_orig  = pd.read_csv(fl_test)

Big_Matrix      = pd.DataFrame(columns=['experiment','num_categ','sample_size','val_accuracy'])

iexp=0
for ilab in experiment_grid['n_labels']:
    for ifrac in experiment_grid['train_frac']:
        iexp+=1
        train, test = select_data(train_orig, test_orig, 'category', ilab, ifrac)
        train, test = factorize_data(train, test, 'category')
        print(f'\nExperiment {iexp} with {ilab} labels and sample fraction of {ifrac}')
        print(f'\nsize of training dataset: {len(train)}')
        print(f'size of testing dataset: {len(test)}')
        colors = sns.color_palette('pastel')[0:ilab]
        _ = plt.pie(list(train['category'].value_counts()), 
                    labels = list(train['category'].value_counts().index), 
                    colors = colors, autopct='%.0f%%')
        _ = plt.title('Class imbalance')
        _ = plt.show()
        
        train_dataset, test_dataset = tokenize_encode_data(train,test,'text','category',checkpoint='distilbert-base-uncased')
        history, fitted_model       = transformer_model(train_dataset,test_dataset,ilab,epochs=30)
        fig, axes   = plt.subplots(1,2,figsize=(15,5))
        epoch_range = np.arange(1,len(history.history['loss'])+1)
        axes[0]   = sns.lineplot(ax=axes[0],x=epoch_range,y=history.history['loss'],label='Training Loss')
        axes[0]   = sns.lineplot(ax=axes[0],x=epoch_range,y=history.history['val_loss'],label='Validation Loss').set_title('Loss')
        axes[1]   = sns.lineplot(ax=axes[1],x=epoch_range,y=history.history['accuracy'],label='Training Accuracy')
        axes[1]   = sns.lineplot(ax=axes[1],x=epoch_range,y=history.history['val_accuracy'],label='Validation Accuracy').set_title('Accuracy')
        _         = plt.show()
        
        Big_Matrix['experiment']   = iexp
        Big_Matrix['num_categ']    = ilab
        Big_Matrix['sample_size']  = ifrac
        Big_Matrix['val_accuracy'] = np.max(history.history['val_accuracy'])
# Out:
# Experiment 1 with 2 labels and sample fraction of 0.1
#
# size of training dataset: 36
# size of testing dataset: 80
# Some layers from the model checkpoint at distilbert-base-uncased were not used when initializing TFDistilBertForSequenceClassification: ['vocab_projector', 'activation_13', 'vocab_transform', 'vocab_layer_norm']
# - This IS expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some layers of TFDistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier', 'dropout_19', 'classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/30
# WARNING:tensorflow:From C:\Users\Windows\anaconda3\envs\tf2.5\lib\site-packages\tensorflow\python\ops\array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# 1/1 [==============================] - 7s 7s/step - loss: 0.6995 - accuracy: 0.5833 - val_loss: 0.6780 - val_accuracy: 0.5500
# Epoch 2/30
# 1/1 [==============================] - 0s 249ms/step - loss: 0.6791 - accuracy: 0.6389 - val_loss: 0.6585 - val_accuracy: 0.8250
# Epoch 3/30
# 1/1 [==============================] - 0s 252ms/step - loss: 0.6359 - accuracy: 0.9444 - val_loss: 0.6304 - val_accuracy: 0.8375
# Epoch 4/30
# 1/1 [==============================] - 0s 261ms/step - loss: 0.5946 - accuracy: 0.8611 - val_loss: 0.5896 - val_accuracy: 0.8375
# Epoch 5/30
# 1/1 [==============================] - 0s 251ms/step - loss: 0.5418 - accuracy: 0.8611 - val_loss: 0.5394 - val_accuracy: 0.8875
# Epoch 6/30
# 1/1 [==============================] - 0s 263ms/step - loss: 0.4627 - accuracy: 0.9167 - val_loss: 0.4893 - val_accuracy: 0.8750
# Epoch 7/30
# 1/1 [==============================] - 0s 252ms/step - loss: 0.3866 - accuracy: 0.9444 - val_loss: 0.4371 - val_accuracy: 0.8750
# Epoch 8/30
# 1/1 [==============================] - 0s 256ms/step - loss: 0.3095 - accuracy: 1.0000 - val_loss: 0.3881 - val_accuracy: 0.8750
# Epoch 9/30
# 1/1 [==============================] - 0s 258ms/step - loss: 0.2547 - accuracy: 1.0000 - val_loss: 0.3356 - val_accuracy: 0.8750
# Epoch 10/30
# 1/1 [==============================] - 0s 250ms/step - loss: 0.1882 - accuracy: 1.0000 - val_loss: 0.2927 - val_accuracy: 0.8750
# Epoch 11/30
# 1/1 [==============================] - 0s 252ms/step - loss: 0.1453 - accuracy: 1.0000 - val_loss: 0.2635 - val_accuracy: 0.8750
# Epoch 12/30
# 1/1 [==============================] - 0s 254ms/step - loss: 0.1095 - accuracy: 1.0000 - val_loss: 0.2451 - val_accuracy: 0.8750
# Epoch 13/30
# 1/1 [==============================] - 0s 250ms/step - loss: 0.0839 - accuracy: 1.0000 - val_loss: 0.2336 - val_accuracy: 0.8750
# Epoch 14/30
# 1/1 [==============================] - 0s 252ms/step - loss: 0.0648 - accuracy: 1.0000 - val_loss: 0.2265 - val_accuracy: 0.8750
# Epoch 15/30
# 1/1 [==============================] - 0s 251ms/step - loss: 0.0522 - accuracy: 1.0000 - val_loss: 0.2219 - val_accuracy: 0.8750
# Epoch 16/30
# 1/1 [==============================] - 0s 258ms/step - loss: 0.0421 - accuracy: 1.0000 - val_loss: 0.2183 - val_accuracy: 0.8750
# Epoch 17/30
# 1/1 [==============================] - 0s 263ms/step - loss: 0.0350 - accuracy: 1.0000 - val_loss: 0.2152 - val_accuracy: 0.9000
# Epoch 18/30
# 1/1 [==============================] - 0s 262ms/step - loss: 0.0286 - accuracy: 1.0000 - val_loss: 0.2133 - val_accuracy: 0.9000
# Epoch 19/30
# 1/1 [==============================] - 0s 263ms/step - loss: 0.0252 - accuracy: 1.0000 - val_loss: 0.2124 - val_accuracy: 0.9000
# Epoch 20/30
# 1/1 [==============================] - 0s 257ms/step - loss: 0.0199 - accuracy: 1.0000 - val_loss: 0.2126 - val_accuracy: 0.9125
# Epoch 21/30
# 1/1 [==============================] - 0s 255ms/step - loss: 0.0173 - accuracy: 1.0000 - val_loss: 0.2139 - val_accuracy: 0.9250
# Epoch 22/30
# 1/1 [==============================] - 0s 258ms/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.2164 - val_accuracy: 0.9250
# Epoch 23/30
# 1/1 [==============================] - 0s 328ms/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.2199 - val_accuracy: 0.9250
# Epoch 24/30
# 1/1 [==============================] - 0s 272ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.2242 - val_accuracy: 0.9250
# Epoch 25/30
# 1/1 [==============================] - 0s 266ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.2289 - val_accuracy: 0.9250
# Epoch 26/30
# 1/1 [==============================] - 0s 265ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.2339 - val_accuracy: 0.9250
# Epoch 27/30
# 1/1 [==============================] - 0s 259ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.2391 - val_accuracy: 0.9250
# Epoch 28/30
# 1/1 [==============================] - 0s 259ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.2444 - val_accuracy: 0.9250
# Epoch 29/30
# 1/1 [==============================] - 0s 265ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.2496 - val_accuracy: 0.9250
# Epoch 30/30
# 1/1 [==============================] - 0s 261ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.2548 - val_accuracy: 0.9250
# Experiment 2 with 2 labels and sample fraction of 0.5
#
# size of training dataset: 184
# size of testing dataset: 80
# Some layers from the model checkpoint at distilbert-base-uncased were not used when initializing TFDistilBertForSequenceClassification: ['vocab_projector', 'activation_13', 'vocab_transform', 'vocab_layer_norm']
# - This IS expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some layers of TFDistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['dropout_39', 'pre_classifier', 'classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/30
# 3/3 [==============================] - 6s 674ms/step - loss: 0.6840 - accuracy: 0.6033 - val_loss: 0.6416 - val_accuracy: 0.9125
# Epoch 2/30
# 3/3 [==============================] - 1s 267ms/step - loss: 0.5894 - accuracy: 0.9239 - val_loss: 0.4781 - val_accuracy: 0.8625
# Epoch 3/30
# 3/3 [==============================] - 1s 265ms/step - loss: 0.3922 - accuracy: 0.9620 - val_loss: 0.2934 - val_accuracy: 0.9125
# Epoch 4/30
# 3/3 [==============================] - 1s 259ms/step - loss: 0.2126 - accuracy: 0.9837 - val_loss: 0.1682 - val_accuracy: 0.9875
# Epoch 5/30
# 3/3 [==============================] - 1s 268ms/step - loss: 0.1129 - accuracy: 0.9891 - val_loss: 0.0972 - val_accuracy: 0.9875
# Epoch 6/30
# 3/3 [==============================] - 1s 266ms/step - loss: 0.0597 - accuracy: 0.9946 - val_loss: 0.0743 - val_accuracy: 0.9750
# Epoch 7/30
# 3/3 [==============================] - 1s 259ms/step - loss: 0.0326 - accuracy: 1.0000 - val_loss: 0.0728 - val_accuracy: 0.9750
# Epoch 8/30
# 3/3 [==============================] - 1s 266ms/step - loss: 0.0192 - accuracy: 1.0000 - val_loss: 0.0786 - val_accuracy: 0.9750
# Epoch 9/30
# 3/3 [==============================] - 1s 262ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.0875 - val_accuracy: 0.9750
# Epoch 10/30
# 3/3 [==============================] - 1s 266ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.0990 - val_accuracy: 0.9750
# Epoch 11/30
# 3/3 [==============================] - 1s 268ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.1131 - val_accuracy: 0.9625
# Epoch 12/30
# 3/3 [==============================] - 1s 268ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.1276 - val_accuracy: 0.9625
# Epoch 13/30
# 3/3 [==============================] - 1s 258ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.1407 - val_accuracy: 0.9625
# Epoch 14/30
# 3/3 [==============================] - 1s 262ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9625
# Epoch 15/30
# 3/3 [==============================] - 1s 263ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.1609 - val_accuracy: 0.9625
# Epoch 16/30
# 3/3 [==============================] - 1s 268ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1672 - val_accuracy: 0.9625
# Epoch 17/30
# 3/3 [==============================] - 1s 259ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1720 - val_accuracy: 0.9250
# Epoch 18/30
# 3/3 [==============================] - 1s 261ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1756 - val_accuracy: 0.9250
# Epoch 19/30
# 3/3 [==============================] - 1s 258ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1785 - val_accuracy: 0.9250
# Epoch 20/30
# 3/3 [==============================] - 1s 269ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1808 - val_accuracy: 0.9250
# Epoch 21/30
# 3/3 [==============================] - 1s 259ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1828 - val_accuracy: 0.9250
# Epoch 22/30
# 3/3 [==============================] - 1s 260ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1845 - val_accuracy: 0.9250
# Epoch 23/30
# 3/3 [==============================] - 1s 258ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1863 - val_accuracy: 0.9250
# Epoch 24/30
# 3/3 [==============================] - 1s 261ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1883 - val_accuracy: 0.9250
# Epoch 25/30
# 3/3 [==============================] - 1s 266ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1899 - val_accuracy: 0.9250
# Epoch 26/30
# 3/3 [==============================] - 1s 257ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1914 - val_accuracy: 0.9250
# Epoch 27/30
# 3/3 [==============================] - 1s 307ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1923 - val_accuracy: 0.9250
# Epoch 28/30
# 3/3 [==============================] - 1s 309ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1930 - val_accuracy: 0.9250
# Epoch 29/30
# 3/3 [==============================] - 1s 321ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1938 - val_accuracy: 0.9250
# Epoch 30/30
# 3/3 [==============================] - 1s 272ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1945 - val_accuracy: 0.9250
# Experiment 3 with 2 labels and sample fraction of 1.0
#
# size of training dataset: 369
# size of testing dataset: 80
# Some layers from the model checkpoint at distilbert-base-uncased were not used when initializing TFDistilBertForSequenceClassification: ['vocab_projector', 'activation_13', 'vocab_transform', 'vocab_layer_norm']
# - This IS expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some layers of TFDistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier', 'classifier', 'dropout_59']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/30
# 6/6 [==============================] - 8s 501ms/step - loss: 0.6253 - accuracy: 0.7344 - val_loss: 0.4084 - val_accuracy: 0.9875
# Epoch 2/30
# 6/6 [==============================] - 2s 338ms/step - loss: 0.2683 - accuracy: 0.9837 - val_loss: 0.1105 - val_accuracy: 1.0000
# Epoch 3/30
# 6/6 [==============================] - 2s 338ms/step - loss: 0.0701 - accuracy: 1.0000 - val_loss: 0.1683 - val_accuracy: 0.9375
# Epoch 4/30
# 6/6 [==============================] - 2s 339ms/step - loss: 0.0256 - accuracy: 1.0000 - val_loss: 0.1679 - val_accuracy: 0.9625
# Epoch 5/30
# 6/6 [==============================] - 2s 341ms/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 0.1765 - val_accuracy: 0.9625
# Epoch 6/30
# 6/6 [==============================] - 2s 339ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.1893 - val_accuracy: 0.9625
# Epoch 7/30
# 6/6 [==============================] - 2s 342ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.1996 - val_accuracy: 0.9625
# Epoch 8/30
# 6/6 [==============================] - 2s 339ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.2076 - val_accuracy: 0.9625
# Epoch 9/30
# 6/6 [==============================] - 2s 340ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.2141 - val_accuracy: 0.9625
# Epoch 10/30
# 6/6 [==============================] - 2s 341ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.2195 - val_accuracy: 0.9625
# Epoch 11/30
# 6/6 [==============================] - 2s 341ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2240 - val_accuracy: 0.9625
# Epoch 12/30
# 6/6 [==============================] - 2s 341ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2280 - val_accuracy: 0.9625
# Epoch 13/30
# 6/6 [==============================] - 2s 342ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.2315 - val_accuracy: 0.9625
# Epoch 14/30
# 6/6 [==============================] - 2s 339ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2348 - val_accuracy: 0.9625
# Epoch 15/30
# 6/6 [==============================] - 2s 342ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2379 - val_accuracy: 0.9625
# Epoch 16/30
# 6/6 [==============================] - 2s 343ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2409 - val_accuracy: 0.9625
# Epoch 17/30
# 6/6 [==============================] - 2s 342ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2438 - val_accuracy: 0.9625
# Epoch 18/30
# 6/6 [==============================] - 2s 341ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2467 - val_accuracy: 0.9625
# Epoch 19/30
# 6/6 [==============================] - 2s 341ms/step - loss: 9.7637e-04 - accuracy: 1.0000 - val_loss: 0.2494 - val_accuracy: 0.9625
# Epoch 20/30
# 6/6 [==============================] - 2s 342ms/step - loss: 9.1989e-04 - accuracy: 1.0000 - val_loss: 0.2521 - val_accuracy: 0.9625
# Epoch 21/30
# 6/6 [==============================] - 2s 342ms/step - loss: 8.5453e-04 - accuracy: 1.0000 - val_loss: 0.2548 - val_accuracy: 0.9625
# Epoch 22/30
# 6/6 [==============================] - 2s 342ms/step - loss: 7.8045e-04 - accuracy: 1.0000 - val_loss: 0.2573 - val_accuracy: 0.9625
# Epoch 23/30
# 6/6 [==============================] - 2s 343ms/step - loss: 7.3355e-04 - accuracy: 1.0000 - val_loss: 0.2597 - val_accuracy: 0.9625
# Epoch 24/30
# 6/6 [==============================] - 2s 365ms/step - loss: 6.9111e-04 - accuracy: 1.0000 - val_loss: 0.2620 - val_accuracy: 0.9625
# Epoch 25/30
# 6/6 [==============================] - 2s 352ms/step - loss: 6.3639e-04 - accuracy: 1.0000 - val_loss: 0.2644 - val_accuracy: 0.9625
# Epoch 26/30
# 6/6 [==============================] - 2s 341ms/step - loss: 5.8902e-04 - accuracy: 1.0000 - val_loss: 0.2666 - val_accuracy: 0.9625
# Epoch 27/30
# 6/6 [==============================] - 2s 341ms/step - loss: 5.4181e-04 - accuracy: 1.0000 - val_loss: 0.2687 - val_accuracy: 0.9625
# Epoch 28/30
# 6/6 [==============================] - 2s 340ms/step - loss: 5.1514e-04 - accuracy: 1.0000 - val_loss: 0.2709 - val_accuracy: 0.9625
# Epoch 29/30
# 6/6 [==============================] - 2s 342ms/step - loss: 4.8731e-04 - accuracy: 1.0000 - val_loss: 0.2731 - val_accuracy: 0.9625
# Epoch 30/30
# 6/6 [==============================] - 2s 357ms/step - loss: 4.6556e-04 - accuracy: 1.0000 - val_loss: 0.2754 - val_accuracy: 0.9625
# Experiment 4 with 5 labels and sample fraction of 0.1
#
# size of training dataset: 90
# size of testing dataset: 200
# Some layers from the model checkpoint at distilbert-base-uncased were not used when initializing TFDistilBertForSequenceClassification: ['vocab_projector', 'activation_13', 'vocab_transform', 'vocab_layer_norm']
# - This IS expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some layers of TFDistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier', 'classifier', 'dropout_79']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/30
# 2/2 [==============================] - 6s 1s/step - loss: 1.5940 - accuracy: 0.3444 - val_loss: 1.5918 - val_accuracy: 0.2200
# Epoch 2/30
# 2/2 [==============================] - 1s 421ms/step - loss: 1.5292 - accuracy: 0.3333 - val_loss: 1.5726 - val_accuracy: 0.2200
# Epoch 3/30
# 2/2 [==============================] - 1s 422ms/step - loss: 1.4597 - accuracy: 0.3111 - val_loss: 1.5261 - val_accuracy: 0.2250
# Epoch 4/30
# 2/2 [==============================] - 1s 422ms/step - loss: 1.3693 - accuracy: 0.3778 - val_loss: 1.4291 - val_accuracy: 0.4050
# Epoch 5/30
# 2/2 [==============================] - 1s 429ms/step - loss: 1.2507 - accuracy: 0.6000 - val_loss: 1.3190 - val_accuracy: 0.5750
# Epoch 6/30
# 2/2 [==============================] - 1s 417ms/step - loss: 1.0844 - accuracy: 0.7778 - val_loss: 1.2093 - val_accuracy: 0.6050
# Epoch 7/30
# 2/2 [==============================] - 1s 429ms/step - loss: 0.9608 - accuracy: 0.8444 - val_loss: 1.0993 - val_accuracy: 0.6600
# Epoch 8/30
# 2/2 [==============================] - 1s 414ms/step - loss: 0.8128 - accuracy: 0.9000 - val_loss: 0.9989 - val_accuracy: 0.7100
# Epoch 9/30
# 2/2 [==============================] - 1s 419ms/step - loss: 0.6903 - accuracy: 0.9222 - val_loss: 0.9016 - val_accuracy: 0.7400
# Epoch 10/30
# 2/2 [==============================] - 1s 419ms/step - loss: 0.5733 - accuracy: 0.9444 - val_loss: 0.8114 - val_accuracy: 0.7550
# Epoch 11/30
# 2/2 [==============================] - 1s 426ms/step - loss: 0.4820 - accuracy: 0.9667 - val_loss: 0.7231 - val_accuracy: 0.8400
# Epoch 12/30
# 2/2 [==============================] - 1s 415ms/step - loss: 0.3866 - accuracy: 1.0000 - val_loss: 0.6485 - val_accuracy: 0.8550
# Epoch 13/30
# 2/2 [==============================] - 1s 432ms/step - loss: 0.3181 - accuracy: 1.0000 - val_loss: 0.5964 - val_accuracy: 0.8500
# Epoch 14/30
# 2/2 [==============================] - 1s 435ms/step - loss: 0.2508 - accuracy: 1.0000 - val_loss: 0.5632 - val_accuracy: 0.8500
# Epoch 15/30
# 2/2 [==============================] - 1s 428ms/step - loss: 0.2131 - accuracy: 1.0000 - val_loss: 0.5225 - val_accuracy: 0.8500
# Epoch 16/30
# 2/2 [==============================] - 1s 419ms/step - loss: 0.1711 - accuracy: 1.0000 - val_loss: 0.4836 - val_accuracy: 0.8900
# Epoch 17/30
# 2/2 [==============================] - 1s 424ms/step - loss: 0.1474 - accuracy: 1.0000 - val_loss: 0.4534 - val_accuracy: 0.9000
# Epoch 18/30
# 2/2 [==============================] - 1s 411ms/step - loss: 0.1255 - accuracy: 1.0000 - val_loss: 0.4356 - val_accuracy: 0.9000
# Epoch 19/30
# 2/2 [==============================] - 1s 419ms/step - loss: 0.1074 - accuracy: 1.0000 - val_loss: 0.4286 - val_accuracy: 0.9000
# Epoch 20/30
# 2/2 [==============================] - 1s 426ms/step - loss: 0.0919 - accuracy: 1.0000 - val_loss: 0.4259 - val_accuracy: 0.9000
# Epoch 21/30
# 2/2 [==============================] - 1s 419ms/step - loss: 0.0773 - accuracy: 1.0000 - val_loss: 0.4230 - val_accuracy: 0.9000
# Epoch 22/30
# 2/2 [==============================] - 1s 415ms/step - loss: 0.0710 - accuracy: 1.0000 - val_loss: 0.4172 - val_accuracy: 0.8950
# Epoch 23/30
# 2/2 [==============================] - 1s 426ms/step - loss: 0.0606 - accuracy: 1.0000 - val_loss: 0.4105 - val_accuracy: 0.9000
# Epoch 24/30
# 2/2 [==============================] - 1s 419ms/step - loss: 0.0572 - accuracy: 1.0000 - val_loss: 0.4039 - val_accuracy: 0.9000
# Epoch 25/30
# 2/2 [==============================] - 1s 419ms/step - loss: 0.0488 - accuracy: 1.0000 - val_loss: 0.3975 - val_accuracy: 0.9000
# Epoch 26/30
# 2/2 [==============================] - 1s 423ms/step - loss: 0.0450 - accuracy: 1.0000 - val_loss: 0.3938 - val_accuracy: 0.9050
# Epoch 27/30
# 2/2 [==============================] - 1s 421ms/step - loss: 0.0411 - accuracy: 1.0000 - val_loss: 0.3918 - val_accuracy: 0.9050
# Epoch 28/30
# 2/2 [==============================] - 1s 425ms/step - loss: 0.0394 - accuracy: 1.0000 - val_loss: 0.3916 - val_accuracy: 0.9050
# Epoch 29/30
# 2/2 [==============================] - 1s 419ms/step - loss: 0.0353 - accuracy: 1.0000 - val_loss: 0.3938 - val_accuracy: 0.9050
# Epoch 30/30
# 2/2 [==============================] - 1s 433ms/step - loss: 0.0331 - accuracy: 1.0000 - val_loss: 0.3961 - val_accuracy: 0.9050
# Experiment 5 with 5 labels and sample fraction of 0.5
#
# size of training dataset: 453
# size of testing dataset: 200
# Some layers from the model checkpoint at distilbert-base-uncased were not used when initializing TFDistilBertForSequenceClassification: ['vocab_projector', 'activation_13', 'vocab_transform', 'vocab_layer_norm']
# - This IS expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some layers of TFDistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier', 'dropout_99', 'classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/30
# 8/8 [==============================] - 8s 412ms/step - loss: 1.5769 - accuracy: 0.2472 - val_loss: 1.4242 - val_accuracy: 0.6050
# Epoch 2/30
# 8/8 [==============================] - 2s 286ms/step - loss: 1.2148 - accuracy: 0.8013 - val_loss: 0.9477 - val_accuracy: 0.8750
# Epoch 3/30
# 8/8 [==============================] - 2s 295ms/step - loss: 0.7291 - accuracy: 0.9095 - val_loss: 0.5333 - val_accuracy: 0.9500
# Epoch 4/30
# 8/8 [==============================] - 2s 283ms/step - loss: 0.3745 - accuracy: 0.9845 - val_loss: 0.3106 - val_accuracy: 0.9500
# Epoch 5/30
# 8/8 [==============================] - 2s 284ms/step - loss: 0.1829 - accuracy: 0.9934 - val_loss: 0.2228 - val_accuracy: 0.9450
# Epoch 6/30
# 8/8 [==============================] - 2s 306ms/step - loss: 0.0974 - accuracy: 0.9978 - val_loss: 0.2018 - val_accuracy: 0.9550
# Epoch 7/30
# 8/8 [==============================] - 2s 302ms/step - loss: 0.0607 - accuracy: 0.9978 - val_loss: 0.1749 - val_accuracy: 0.9500
# Epoch 8/30
# 8/8 [==============================] - 2s 292ms/step - loss: 0.0406 - accuracy: 1.0000 - val_loss: 0.2018 - val_accuracy: 0.9450
# Epoch 9/30
# 8/8 [==============================] - 2s 285ms/step - loss: 0.0300 - accuracy: 1.0000 - val_loss: 0.1863 - val_accuracy: 0.9450
# Epoch 10/30
# 8/8 [==============================] - 2s 283ms/step - loss: 0.0238 - accuracy: 1.0000 - val_loss: 0.2038 - val_accuracy: 0.9450
# Epoch 11/30
# 8/8 [==============================] - 2s 284ms/step - loss: 0.0199 - accuracy: 1.0000 - val_loss: 0.2232 - val_accuracy: 0.9450
# Epoch 12/30
# 8/8 [==============================] - 2s 288ms/step - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.2181 - val_accuracy: 0.9500
# Epoch 13/30
# 8/8 [==============================] - 2s 290ms/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.2171 - val_accuracy: 0.9500
# Epoch 14/30
# 8/8 [==============================] - 2s 298ms/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.2143 - val_accuracy: 0.9500
# Epoch 15/30
# 8/8 [==============================] - 2s 316ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.2148 - val_accuracy: 0.9500
# Epoch 16/30
# 8/8 [==============================] - 2s 292ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.2163 - val_accuracy: 0.9500
# Epoch 17/30
# 8/8 [==============================] - 2s 288ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.2187 - val_accuracy: 0.9500
# Epoch 18/30
# 8/8 [==============================] - 2s 290ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.2202 - val_accuracy: 0.9500
# Epoch 19/30
# 8/8 [==============================] - 2s 300ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.2206 - val_accuracy: 0.9500
# Epoch 20/30
# 8/8 [==============================] - 2s 290ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.2224 - val_accuracy: 0.9500
# Epoch 21/30
# 8/8 [==============================] - 2s 286ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.2243 - val_accuracy: 0.9500
# Epoch 22/30
# 8/8 [==============================] - 2s 299ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.2276 - val_accuracy: 0.9500
# Epoch 23/30
# 8/8 [==============================] - 2s 315ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.2307 - val_accuracy: 0.9500
# Epoch 24/30
# 8/8 [==============================] - 2s 286ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.2316 - val_accuracy: 0.9500
# Epoch 25/30
# 8/8 [==============================] - 3s 320ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.2316 - val_accuracy: 0.9500
# Epoch 26/30
# 8/8 [==============================] - 2s 286ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.2322 - val_accuracy: 0.9500
# Epoch 27/30
# 8/8 [==============================] - 2s 287ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.2344 - val_accuracy: 0.9500
# Epoch 28/30
# 8/8 [==============================] - 2s 298ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.2357 - val_accuracy: 0.9500
# Epoch 29/30
# 8/8 [==============================] - 2s 308ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.2370 - val_accuracy: 0.9500
# Epoch 30/30
# 8/8 [==============================] - 2s 292ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.2381 - val_accuracy: 0.9500
# Experiment 6 with 5 labels and sample fraction of 1.0
#
# size of training dataset: 907
# size of testing dataset: 200
# Some layers from the model checkpoint at distilbert-base-uncased were not used when initializing TFDistilBertForSequenceClassification: ['vocab_projector', 'activation_13', 'vocab_transform', 'vocab_layer_norm']
# - This IS expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some layers of TFDistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier', 'dropout_119', 'classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/30
# 15/15 [==============================] - 11s 412ms/step - loss: 1.4397 - accuracy: 0.4730 - val_loss: 0.9999 - val_accuracy: 0.8550
# Epoch 2/30
# 15/15 [==============================] - 5s 336ms/step - loss: 0.6607 - accuracy: 0.9658 - val_loss: 0.2926 - val_accuracy: 0.9900
# Epoch 3/30
# 15/15 [==============================] - 5s 336ms/step - loss: 0.1904 - accuracy: 0.9879 - val_loss: 0.0968 - val_accuracy: 0.9950
# Epoch 4/30
# 15/15 [==============================] - 5s 347ms/step - loss: 0.0711 - accuracy: 0.9967 - val_loss: 0.0639 - val_accuracy: 0.9900
# Epoch 5/30
# 15/15 [==============================] - 5s 345ms/step - loss: 0.0381 - accuracy: 0.9989 - val_loss: 0.0516 - val_accuracy: 0.9900
# Epoch 6/30
# 15/15 [==============================] - 5s 351ms/step - loss: 0.0313 - accuracy: 0.9978 - val_loss: 0.0353 - val_accuracy: 0.9950
# Epoch 7/30
# 15/15 [==============================] - 5s 358ms/step - loss: 0.0516 - accuracy: 0.9890 - val_loss: 0.0769 - val_accuracy: 0.9750
# Epoch 8/30
# 15/15 [==============================] - 5s 360ms/step - loss: 0.0349 - accuracy: 0.9934 - val_loss: 0.0593 - val_accuracy: 0.9900
# Epoch 9/30
# 15/15 [==============================] - 5s 358ms/step - loss: 0.0199 - accuracy: 0.9978 - val_loss: 0.0653 - val_accuracy: 0.9750
# Epoch 10/30
# 15/15 [==============================] - 5s 342ms/step - loss: 0.0108 - accuracy: 0.9989 - val_loss: 0.0492 - val_accuracy: 0.9850
# Epoch 11/30
# 15/15 [==============================] - 5s 349ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.0416 - val_accuracy: 0.9900
# Epoch 12/30
# 15/15 [==============================] - 5s 337ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.0412 - val_accuracy: 0.9900
# Epoch 13/30
# 15/15 [==============================] - 5s 338ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.0433 - val_accuracy: 0.9900
# Epoch 14/30
# 15/15 [==============================] - 5s 338ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0456 - val_accuracy: 0.9900
# Epoch 15/30
# 15/15 [==============================] - 5s 338ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0463 - val_accuracy: 0.9900
# Epoch 16/30
# 15/15 [==============================] - 5s 342ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0466 - val_accuracy: 0.9900
# Epoch 17/30
# 15/15 [==============================] - 5s 337ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0468 - val_accuracy: 0.9900
# Epoch 18/30
# 15/15 [==============================] - 5s 337ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0469 - val_accuracy: 0.9900
# Epoch 19/30
# 15/15 [==============================] - 5s 337ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0475 - val_accuracy: 0.9900
# Epoch 20/30
# 15/15 [==============================] - 5s 348ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0478 - val_accuracy: 0.9900
# Epoch 21/30
# 15/15 [==============================] - 5s 339ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0479 - val_accuracy: 0.9900
# Epoch 22/30
# 15/15 [==============================] - 5s 340ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0480 - val_accuracy: 0.9900
# Epoch 23/30
# 15/15 [==============================] - 5s 349ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0482 - val_accuracy: 0.9900
# Epoch 24/30
# 15/15 [==============================] - 5s 336ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0483 - val_accuracy: 0.9900
# Epoch 25/30
# 15/15 [==============================] - 5s 338ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0485 - val_accuracy: 0.9900
# Epoch 26/30
# 15/15 [==============================] - 5s 342ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0486 - val_accuracy: 0.9900
# Epoch 27/30
# 15/15 [==============================] - 5s 344ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0488 - val_accuracy: 0.9900
# Epoch 28/30
# 15/15 [==============================] - 5s 340ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0489 - val_accuracy: 0.9900
# Epoch 29/30
# 15/15 [==============================] - 5s 338ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0491 - val_accuracy: 0.9900
# Epoch 30/30
# 15/15 [==============================] - 5s 338ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0494 - val_accuracy: 0.9900
# Experiment 7 with 10 labels and sample fraction of 0.1
#
# size of training dataset: 176
# size of testing dataset: 400
# Some layers from the model checkpoint at distilbert-base-uncased were not used when initializing TFDistilBertForSequenceClassification: ['vocab_projector', 'activation_13', 'vocab_transform', 'vocab_layer_norm']
# - This IS expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some layers of TFDistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['dropout_139', 'pre_classifier', 'classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/30
# 3/3 [==============================] - 7s 1s/step - loss: 2.2975 - accuracy: 0.1250 - val_loss: 2.2832 - val_accuracy: 0.1800
# Epoch 2/30
# 3/3 [==============================] - 2s 699ms/step - loss: 2.2396 - accuracy: 0.2841 - val_loss: 2.2414 - val_accuracy: 0.2800
# Epoch 3/30
# 3/3 [==============================] - 2s 691ms/step - loss: 2.1559 - accuracy: 0.3693 - val_loss: 2.1710 - val_accuracy: 0.3075
# Epoch 4/30
# 3/3 [==============================] - 2s 681ms/step - loss: 2.0333 - accuracy: 0.4886 - val_loss: 2.0719 - val_accuracy: 0.3625
# Epoch 5/30
# 3/3 [==============================] - 2s 822ms/step - loss: 1.8930 - accuracy: 0.5909 - val_loss: 1.9490 - val_accuracy: 0.4225
# Epoch 6/30
# 3/3 [==============================] - 2s 692ms/step - loss: 1.7306 - accuracy: 0.7045 - val_loss: 1.8089 - val_accuracy: 0.5300
# Epoch 7/30
# 3/3 [==============================] - 2s 689ms/step - loss: 1.5533 - accuracy: 0.7841 - val_loss: 1.6716 - val_accuracy: 0.5850
# Epoch 8/30
# 3/3 [==============================] - 2s 694ms/step - loss: 1.3705 - accuracy: 0.8409 - val_loss: 1.5072 - val_accuracy: 0.6600
# Epoch 9/30
# 3/3 [==============================] - 2s 695ms/step - loss: 1.1910 - accuracy: 0.9205 - val_loss: 1.3598 - val_accuracy: 0.7375
# Epoch 10/30
# 3/3 [==============================] - 2s 686ms/step - loss: 1.0260 - accuracy: 0.9602 - val_loss: 1.1938 - val_accuracy: 0.8125
# Epoch 11/30
# 3/3 [==============================] - 2s 696ms/step - loss: 0.8634 - accuracy: 0.9886 - val_loss: 1.0710 - val_accuracy: 0.8175
# Epoch 12/30
# 3/3 [==============================] - 2s 693ms/step - loss: 0.7238 - accuracy: 0.9886 - val_loss: 0.9184 - val_accuracy: 0.8450
# Epoch 13/30
# 3/3 [==============================] - 2s 691ms/step - loss: 0.5900 - accuracy: 0.9943 - val_loss: 0.8173 - val_accuracy: 0.8525
# Epoch 14/30
# 3/3 [==============================] - 2s 702ms/step - loss: 0.4919 - accuracy: 1.0000 - val_loss: 0.7175 - val_accuracy: 0.8675
# Epoch 15/30
# 3/3 [==============================] - 2s 691ms/step - loss: 0.3962 - accuracy: 1.0000 - val_loss: 0.6295 - val_accuracy: 0.8850
# Epoch 16/30
# 3/3 [==============================] - 2s 696ms/step - loss: 0.3260 - accuracy: 1.0000 - val_loss: 0.5730 - val_accuracy: 0.8700
# Epoch 17/30
# 3/3 [==============================] - 2s 686ms/step - loss: 0.2719 - accuracy: 1.0000 - val_loss: 0.5285 - val_accuracy: 0.8775
# Epoch 18/30
# 3/3 [==============================] - 2s 685ms/step - loss: 0.2261 - accuracy: 1.0000 - val_loss: 0.4739 - val_accuracy: 0.8875
# Epoch 19/30
# 3/3 [==============================] - 2s 681ms/step - loss: 0.1895 - accuracy: 1.0000 - val_loss: 0.4385 - val_accuracy: 0.8950
# Epoch 20/30
# 3/3 [==============================] - 2s 686ms/step - loss: 0.1613 - accuracy: 1.0000 - val_loss: 0.4205 - val_accuracy: 0.8925
# Epoch 21/30
# 3/3 [==============================] - 2s 695ms/step - loss: 0.1423 - accuracy: 1.0000 - val_loss: 0.4023 - val_accuracy: 0.8825
# Epoch 22/30
# 3/3 [==============================] - 2s 689ms/step - loss: 0.1214 - accuracy: 1.0000 - val_loss: 0.3849 - val_accuracy: 0.9000
# Epoch 23/30
# 3/3 [==============================] - 2s 690ms/step - loss: 0.1062 - accuracy: 1.0000 - val_loss: 0.3661 - val_accuracy: 0.9000
# Epoch 24/30
# 3/3 [==============================] - 2s 691ms/step - loss: 0.0977 - accuracy: 1.0000 - val_loss: 0.3591 - val_accuracy: 0.8925
# Epoch 25/30
# 3/3 [==============================] - 2s 687ms/step - loss: 0.0870 - accuracy: 1.0000 - val_loss: 0.3491 - val_accuracy: 0.8950
# Epoch 26/30
# 3/3 [==============================] - 2s 693ms/step - loss: 0.0782 - accuracy: 1.0000 - val_loss: 0.3398 - val_accuracy: 0.8950
# Epoch 27/30
# 3/3 [==============================] - 2s 685ms/step - loss: 0.0686 - accuracy: 1.0000 - val_loss: 0.3337 - val_accuracy: 0.8900
# Epoch 28/30
# 3/3 [==============================] - 2s 678ms/step - loss: 0.0649 - accuracy: 1.0000 - val_loss: 0.3279 - val_accuracy: 0.8950
# Epoch 29/30
# 3/3 [==============================] - 2s 692ms/step - loss: 0.0604 - accuracy: 1.0000 - val_loss: 0.3241 - val_accuracy: 0.8950
# Epoch 30/30
# 3/3 [==============================] - 2s 688ms/step - loss: 0.0565 - accuracy: 1.0000 - val_loss: 0.3198 - val_accuracy: 0.8950
# Experiment 8 with 10 labels and sample fraction of 0.5
#
# size of training dataset: 884
# size of testing dataset: 400
# Some layers from the model checkpoint at distilbert-base-uncased were not used when initializing TFDistilBertForSequenceClassification: ['vocab_projector', 'activation_13', 'vocab_transform', 'vocab_layer_norm']
# - This IS expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some layers of TFDistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier', 'classifier', 'dropout_159']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/30
