# %% [markdown]
# ## How to quantify F1-Score when fine-tuning pre-trained transformers for NLP tasks?
#
# #### Example

# %% [markdown]
# #### Libraries

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import transformers
from transformers import AutoTokenizer
from transformers import TFAutoModelForSequenceClassification
import tensorflow as tf
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.callbacks import Callback
import sklearn
from sklearn.metrics import confusion_matrix,f1_score,precision_score,recall_score 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

print(f"Tensorflow version: {tf.__version__}")
print(f"Sklearn version: {sklearn.__version__}")
print(f"Transformers version: {transformers.__version__}")

physical_devices = tf.config.list_physical_devices('GPU') 
for device in physical_devices:
    tf.config.experimental.set_memory_growth(device, True)
    
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Tensorflow version: 2.5.0
# Sklearn version: 1.0
# Transformers version: 4.11.3
# Num GPUs Available:  1

# %% [markdown]
# #### I/O Files & Params

# %%
fl_train        = '../datasets/banking77/train.csv'
fl_test         = '../datasets/banking77/test.csv'

checkpoint      ='distilbert-base-uncased'

experiment_grid = {
    'n_labels'  : [4],
    'n_train_inst': [10]
}

seed = 0
BIG_int = 10**21
n_epochs = 50

# %% [markdown]
# #### Functions

# %%
class Metrics(Callback):
    def __init__(self, validation_data):
        super(Metrics, self).__init__()
        self.validation_data = validation_data
        
    def on_train_begin(self, logs={}):
        self.val_f1s = []
        self.val_recalls = []
        self.val_precisions = []
 
    def on_epoch_end(self, epoch, logs={}):
        val_predict = np.argmax(tf.nn.softmax(self.model.predict(self.validation_data[0]).logits),1)
        val_targ = self.validation_data[1]
        val_f1 = f1_score(val_targ, val_predict, average='macro')
        val_recall = recall_score(val_targ, val_predict, average='macro')
        val_precision = precision_score(val_targ, val_predict, average='macro')
        logs['val_f1'] = val_f1
        logs['val_recall'] = val_recall
        logs['val_precision'] = val_precision
        print (f'— val_f1: {round(val_f1,4)} — val_precision: {round(val_precision,4)} — val_recall: {round(val_recall,4)}')
        return

def select_data_instances(train, test, col_label, n_labels=None, n_train_inst=None):
    if n_labels is None:
        n_labels = len(train.loc[:,col_label].unique())
    if n_train_inst is None:
        n_train_inst = BIG_int 
        
    select_labels = np.array(train.loc[:,col_label].value_counts()[0:n_labels].index)
    select_train  = train.loc[train[col_label].isin(select_labels),:].reset_index(drop=True)
    subset_train  = pd.DataFrame(columns=select_train.columns)
    for label in select_labels:
        temp_train   = select_train.loc[select_train[col_label]==label,:].reset_index(drop=True)
        select_indx  = np.random.choice(range(len(temp_train)),min(n_train_inst,len(temp_train)))
        temp_train   = temp_train.iloc[select_indx,:]
        subset_train = subset_train.append(temp_train)
    subset_train = subset_train.sample(frac=1).reset_index(drop=True)
    select_test  = test.loc[test[col_label].isin(select_labels),:].reset_index(drop=True)
    select_test  = select_test.sample(frac=1).reset_index(drop=True)
    return subset_train, select_test 

def factorize_data(train, test, col_label,return_keys=False):
    train_labels, levels = pd.factorize(train.loc[:,col_label])
    categs = pd.concat([train.loc[:,col_label],pd.Series(train_labels)],axis=1).groupby(col_label).mean().index
    labels = pd.concat([train.loc[:,col_label],pd.Series(train_labels)],axis=1).groupby(col_label).mean().values.T[0]
    label_keys=dict(zip(categs,labels))
    test_labels = test.loc[:,col_label].map(lambda x: label_keys[x])
    train.loc[:,col_label]=train_labels
    test.loc[:,col_label]=test_labels
    if return_keys:
        return train, test, label_keys
    else:
        return train, test
    
def tokenize_encode_data(train,test,col_text,col_label,checkpoint,
                         truncation_flag=True, padding_flag=True, return_tensors_opt='np'):
    train_sentences = list(train.loc[:,col_text])
    test_sentences  = list(test.loc[:,col_text])
    train_labels    = list(train.loc[:,col_label])
    test_labels     = list(test.loc[:,col_label])
    tokenizer       = AutoTokenizer.from_pretrained(checkpoint)
    train_encodings = tokenizer(train_sentences, truncation=truncation_flag,
                                padding=padding_flag, return_tensors=return_tensors_opt)
    test_encodings  = tokenizer(test_sentences, truncation=truncation_flag,
                                padding=padding_flag, return_tensors=return_tensors_opt)
    return train_encodings.data, train_labels, test_encodings.data, test_labels 

def transformer_model_compile(checkpoint,n_labels,lr=5e-5):
    model = TFAutoModelForSequenceClassification.from_pretrained(checkpoint, num_labels=n_labels)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
                  loss=SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])
    return model

def transformer_model_fit(model, train_encodings, train_labels, test_encodings, test_labels,epochs=10,batch_size=64):
    history = model.fit(train_encodings,np.array(train_labels),epochs=epochs,batch_size=batch_size,
          validation_data=(test_encodings, np.array(test_labels)),callbacks=[Metrics(validation_data)])
    return history, model

# %%
np.random.seed(seed)
train_orig = pd.read_csv(fl_train)
test_orig  = pd.read_csv(fl_test)

iexp=0
for ilab in experiment_grid['n_labels']:
    compiled_model = transformer_model_compile(checkpoint,ilab)
    for i_ninst in experiment_grid['n_train_inst']:
        iexp+=1
        train, test = select_data_instances(train_orig, test_orig, 'category', ilab, i_ninst)
        train, test = factorize_data(train, test, 'category')
        
        train_encodings, train_labels, test_encodings, test_labels = tokenize_encode_data(train,test,'text',
                                                                                          'category',checkpoint)
        validation_data                                            =(test_encodings, np.array(test_labels))
        
        history, fitted_model = transformer_model_fit(compiled_model,train_encodings,train_labels,
                                                      test_encodings, test_labels,epochs=n_epochs)

        fig, axes   = plt.subplots(1,3,figsize=(15,5))
        epoch_range = np.arange(1,len(history.history['loss'])+1)
        axes[0]   = sns.lineplot(ax=axes[0],x=epoch_range,y=history.history['loss'],label='Training Loss')
        axes[0]   = sns.lineplot(ax=axes[0],x=epoch_range,y=history.history['val_loss'],label='Validation Loss').set_title('Loss')
        axes[1]   = sns.lineplot(ax=axes[1],x=epoch_range,y=history.history['accuracy'],label='Training Accuracy')
        axes[1]   = sns.lineplot(ax=axes[1],x=epoch_range,y=history.history['val_accuracy'],label='Validation Accuracy').set_title('Accuracy')
        axes[2]   = sns.lineplot(ax=axes[2],x=epoch_range,y=history.history['val_precision'],label='Validation Precision')
        axes[2]   = sns.lineplot(ax=axes[2],x=epoch_range,y=history.history['val_recall'],label='Validation Recall')
        axes[2]   = sns.lineplot(ax=axes[2],x=epoch_range,y=history.history['val_f1'],label='Validation f1_score(macro)').set_title('Precision/Recall/f1_score')
        axes[1].set_ylim=(0, 1)
        axes[2].set_ylim=(0, 1)
        _         = plt.show()
# Out:
# Some layers from the model checkpoint at distilbert-base-uncased were not used when initializing TFDistilBertForSequenceClassification: ['activation_13', 'vocab_layer_norm', 'vocab_projector', 'vocab_transform']
# - This IS expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some layers of TFDistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier', 'classifier', 'dropout_19']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\Windows\anaconda3\envs\tf2.5\lib\site-packages\tensorflow\python\ops\array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# 1/1 [==============================] - 8s 8s/step - loss: 1.3895 - accuracy: 0.2250 - val_loss: 1.3775 - val_accuracy: 0.3375
# — val_f1: 0.228 — val_precision: 0.2279 — val_recall: 0.3375
# Epoch 2/50
# 1/1 [==============================] - 0s 370ms/step - loss: 1.3802 - accuracy: 0.2750 - val_loss: 1.3632 - val_accuracy: 0.4250
# — val_f1: 0.2982 — val_precision: 0.4584 — val_recall: 0.425
# Epoch 3/50
# 1/1 [==============================] - 0s 368ms/step - loss: 1.3528 - accuracy: 0.4500 - val_loss: 1.3416 - val_accuracy: 0.4812
# — val_f1: 0.4529 — val_precision: 0.7633 — val_recall: 0.4812
# Epoch 4/50
# 1/1 [==============================] - 0s 367ms/step - loss: 1.3234 - accuracy: 0.5750 - val_loss: 1.3137 - val_accuracy: 0.5625
# — val_f1: 0.5706 — val_precision: 0.8176 — val_recall: 0.5625
# Epoch 5/50
# 1/1 [==============================] - 0s 369ms/step - loss: 1.2676 - accuracy: 0.7750 - val_loss: 1.2713 - val_accuracy: 0.6687
# — val_f1: 0.6801 — val_precision: 0.8473 — val_recall: 0.6688
# Epoch 6/50
# 1/1 [==============================] - 0s 373ms/step - loss: 1.2062 - accuracy: 0.7500 - val_loss: 1.2146 - val_accuracy: 0.7188
# — val_f1: 0.729 — val_precision: 0.8615 — val_recall: 0.7188
# Epoch 7/50
# 1/1 [==============================] - 0s 375ms/step - loss: 1.1311 - accuracy: 0.9000 - val_loss: 1.1458 - val_accuracy: 0.8062
# — val_f1: 0.8096 — val_precision: 0.8743 — val_recall: 0.8062
# Epoch 8/50
# 1/1 [==============================] - 0s 371ms/step - loss: 1.0530 - accuracy: 0.9500 - val_loss: 1.0687 - val_accuracy: 0.8750
# — val_f1: 0.8748 — val_precision: 0.9001 — val_recall: 0.875
# Epoch 9/50
# 1/1 [==============================] - 0s 369ms/step - loss: 0.9505 - accuracy: 1.0000 - val_loss: 0.9899 - val_accuracy: 0.8875
# — val_f1: 0.8855 — val_precision: 0.9036 — val_recall: 0.8875
# Epoch 10/50
# 1/1 [==============================] - 0s 372ms/step - loss: 0.8721 - accuracy: 1.0000 - val_loss: 0.9131 - val_accuracy: 0.8938
# — val_f1: 0.8911 — val_precision: 0.9076 — val_recall: 0.8938
# Epoch 11/50
# 1/1 [==============================] - 0s 373ms/step - loss: 0.7724 - accuracy: 1.0000 - val_loss: 0.8360 - val_accuracy: 0.8938
# — val_f1: 0.8905 — val_precision: 0.9056 — val_recall: 0.8938
# Epoch 12/50
# 1/1 [==============================] - 0s 378ms/step - loss: 0.6706 - accuracy: 1.0000 - val_loss: 0.7639 - val_accuracy: 0.9000
# — val_f1: 0.8966 — val_precision: 0.9126 — val_recall: 0.9
# Epoch 13/50
# 1/1 [==============================] - 0s 371ms/step - loss: 0.6057 - accuracy: 1.0000 - val_loss: 0.6985 - val_accuracy: 0.8938
# — val_f1: 0.8893 — val_precision: 0.9068 — val_recall: 0.8938
# Epoch 14/50
# 1/1 [==============================] - 0s 398ms/step - loss: 0.5256 - accuracy: 1.0000 - val_loss: 0.6399 - val_accuracy: 0.8938
# — val_f1: 0.8893 — val_precision: 0.9068 — val_recall: 0.8938
# Epoch 15/50
# 1/1 [==============================] - 0s 369ms/step - loss: 0.4518 - accuracy: 1.0000 - val_loss: 0.5853 - val_accuracy: 0.8875
# — val_f1: 0.8836 — val_precision: 0.9028 — val_recall: 0.8875
# Epoch 16/50
# 1/1 [==============================] - 0s 370ms/step - loss: 0.3982 - accuracy: 1.0000 - val_loss: 0.5370 - val_accuracy: 0.8938
# — val_f1: 0.8893 — val_precision: 0.9068 — val_recall: 0.8938
# Epoch 17/50
# 1/1 [==============================] - 0s 367ms/step - loss: 0.3424 - accuracy: 1.0000 - val_loss: 0.4950 - val_accuracy: 0.8938
# — val_f1: 0.8893 — val_precision: 0.9068 — val_recall: 0.8938
# Epoch 18/50
# 1/1 [==============================] - 0s 366ms/step - loss: 0.3029 - accuracy: 1.0000 - val_loss: 0.4597 - val_accuracy: 0.9000
# — val_f1: 0.8966 — val_precision: 0.9126 — val_recall: 0.9
# Epoch 19/50
# 1/1 [==============================] - 0s 455ms/step - loss: 0.2681 - accuracy: 1.0000 - val_loss: 0.4291 - val_accuracy: 0.9000
# — val_f1: 0.8966 — val_precision: 0.9126 — val_recall: 0.9
# Epoch 20/50
# 1/1 [==============================] - 0s 373ms/step - loss: 0.2399 - accuracy: 1.0000 - val_loss: 0.4032 - val_accuracy: 0.8938
# — val_f1: 0.8904 — val_precision: 0.9038 — val_recall: 0.8938
# Epoch 21/50
# 1/1 [==============================] - 0s 378ms/step - loss: 0.2051 - accuracy: 1.0000 - val_loss: 0.3821 - val_accuracy: 0.8938
# — val_f1: 0.8904 — val_precision: 0.9038 — val_recall: 0.8938
# Epoch 22/50
# 1/1 [==============================] - 0s 369ms/step - loss: 0.1816 - accuracy: 1.0000 - val_loss: 0.3647 - val_accuracy: 0.8938
# — val_f1: 0.891 — val_precision: 0.906 — val_recall: 0.8938
# Epoch 23/50
# 1/1 [==============================] - 0s 373ms/step - loss: 0.1654 - accuracy: 1.0000 - val_loss: 0.3497 - val_accuracy: 0.9062
# — val_f1: 0.904 — val_precision: 0.9168 — val_recall: 0.9062
# Epoch 24/50
# 1/1 [==============================] - 0s 400ms/step - loss: 0.1442 - accuracy: 1.0000 - val_loss: 0.3364 - val_accuracy: 0.9062
# — val_f1: 0.904 — val_precision: 0.9168 — val_recall: 0.9062
# Epoch 25/50
# 1/1 [==============================] - 0s 399ms/step - loss: 0.1243 - accuracy: 1.0000 - val_loss: 0.3255 - val_accuracy: 0.9062
# — val_f1: 0.904 — val_precision: 0.9168 — val_recall: 0.9062
# Epoch 26/50
# 1/1 [==============================] - 0s 374ms/step - loss: 0.1175 - accuracy: 1.0000 - val_loss: 0.3160 - val_accuracy: 0.9062
# — val_f1: 0.904 — val_precision: 0.9168 — val_recall: 0.9062
# Epoch 27/50
# 1/1 [==============================] - 0s 402ms/step - loss: 0.1027 - accuracy: 1.0000 - val_loss: 0.3073 - val_accuracy: 0.9062
# — val_f1: 0.904 — val_precision: 0.9168 — val_recall: 0.9062
# Epoch 28/50
# 1/1 [==============================] - 0s 377ms/step - loss: 0.0962 - accuracy: 1.0000 - val_loss: 0.3003 - val_accuracy: 0.9062
# — val_f1: 0.904 — val_precision: 0.9168 — val_recall: 0.9062
# Epoch 29/50
# 1/1 [==============================] - 0s 370ms/step - loss: 0.0862 - accuracy: 1.0000 - val_loss: 0.2947 - val_accuracy: 0.9062
# — val_f1: 0.9035 — val_precision: 0.9147 — val_recall: 0.9062
# Epoch 30/50
# 1/1 [==============================] - 0s 376ms/step - loss: 0.0797 - accuracy: 1.0000 - val_loss: 0.2900 - val_accuracy: 0.9062
# — val_f1: 0.9035 — val_precision: 0.9147 — val_recall: 0.9062
# Epoch 31/50
# 1/1 [==============================] - 0s 371ms/step - loss: 0.0725 - accuracy: 1.0000 - val_loss: 0.2865 - val_accuracy: 0.9062
# — val_f1: 0.9035 — val_precision: 0.9147 — val_recall: 0.9062
# Epoch 32/50
# 1/1 [==============================] - 0s 376ms/step - loss: 0.0653 - accuracy: 1.0000 - val_loss: 0.2836 - val_accuracy: 0.9062
# — val_f1: 0.9035 — val_precision: 0.9147 — val_recall: 0.9062
# Epoch 33/50
# 1/1 [==============================] - 0s 370ms/step - loss: 0.0622 - accuracy: 1.0000 - val_loss: 0.2810 - val_accuracy: 0.9062
# — val_f1: 0.9035 — val_precision: 0.9147 — val_recall: 0.9062
# Epoch 34/50
# 1/1 [==============================] - 0s 370ms/step - loss: 0.0575 - accuracy: 1.0000 - val_loss: 0.2787 - val_accuracy: 0.9062
# — val_f1: 0.9035 — val_precision: 0.9147 — val_recall: 0.9062
# Epoch 35/50
# 1/1 [==============================] - 0s 408ms/step - loss: 0.0507 - accuracy: 1.0000 - val_loss: 0.2770 - val_accuracy: 0.9062
# — val_f1: 0.9035 — val_precision: 0.9147 — val_recall: 0.9062
# Epoch 36/50
# 1/1 [==============================] - 0s 372ms/step - loss: 0.0481 - accuracy: 1.0000 - val_loss: 0.2760 - val_accuracy: 0.9062
# — val_f1: 0.9035 — val_precision: 0.9147 — val_recall: 0.9062
# Epoch 37/50
# 1/1 [==============================] - 0s 374ms/step - loss: 0.0452 - accuracy: 1.0000 - val_loss: 0.2754 - val_accuracy: 0.9062
# — val_f1: 0.9035 — val_precision: 0.9147 — val_recall: 0.9062
# Epoch 38/50
# 1/1 [==============================] - 0s 373ms/step - loss: 0.0415 - accuracy: 1.0000 - val_loss: 0.2753 - val_accuracy: 0.9062
# — val_f1: 0.9035 — val_precision: 0.9147 — val_recall: 0.9062
# Epoch 39/50
# 1/1 [==============================] - 0s 375ms/step - loss: 0.0400 - accuracy: 1.0000 - val_loss: 0.2756 - val_accuracy: 0.9062
# — val_f1: 0.9035 — val_precision: 0.9147 — val_recall: 0.9062
# Epoch 40/50
# 1/1 [==============================] - 0s 389ms/step - loss: 0.0405 - accuracy: 1.0000 - val_loss: 0.2761 - val_accuracy: 0.9062
# — val_f1: 0.9035 — val_precision: 0.9147 — val_recall: 0.9062
# Epoch 41/50
# 1/1 [==============================] - 0s 414ms/step - loss: 0.0356 - accuracy: 1.0000 - val_loss: 0.2771 - val_accuracy: 0.9062
# — val_f1: 0.9035 — val_precision: 0.9147 — val_recall: 0.9062
# Epoch 42/50
# 1/1 [==============================] - 0s 390ms/step - loss: 0.0326 - accuracy: 1.0000 - val_loss: 0.2782 - val_accuracy: 0.9062
# — val_f1: 0.9035 — val_precision: 0.9147 — val_recall: 0.9062
# Epoch 43/50
# 1/1 [==============================] - 0s 373ms/step - loss: 0.0313 - accuracy: 1.0000 - val_loss: 0.2795 - val_accuracy: 0.9062
# — val_f1: 0.9035 — val_precision: 0.9147 — val_recall: 0.9062
# Epoch 44/50
# 1/1 [==============================] - 0s 375ms/step - loss: 0.0313 - accuracy: 1.0000 - val_loss: 0.2809 - val_accuracy: 0.9062
# — val_f1: 0.9035 — val_precision: 0.9147 — val_recall: 0.9062
# Epoch 45/50
# 1/1 [==============================] - 0s 377ms/step - loss: 0.0282 - accuracy: 1.0000 - val_loss: 0.2824 - val_accuracy: 0.9062
# — val_f1: 0.9035 — val_precision: 0.9147 — val_recall: 0.9062
# Epoch 46/50
# 1/1 [==============================] - 0s 397ms/step - loss: 0.0267 - accuracy: 1.0000 - val_loss: 0.2841 - val_accuracy: 0.9062
# — val_f1: 0.9035 — val_precision: 0.9147 — val_recall: 0.9062
# Epoch 47/50
# 1/1 [==============================] - 0s 372ms/step - loss: 0.0257 - accuracy: 1.0000 - val_loss: 0.2858 - val_accuracy: 0.9062
# — val_f1: 0.9035 — val_precision: 0.9147 — val_recall: 0.9062
# Epoch 48/50
# 1/1 [==============================] - 0s 461ms/step - loss: 0.0249 - accuracy: 1.0000 - val_loss: 0.2876 - val_accuracy: 0.9062
# — val_f1: 0.9035 — val_precision: 0.9147 — val_recall: 0.9062
# Epoch 49/50
# 1/1 [==============================] - 0s 382ms/step - loss: 0.0233 - accuracy: 1.0000 - val_loss: 0.2895 - val_accuracy: 0.9062
# — val_f1: 0.9035 — val_precision: 0.9147 — val_recall: 0.9062
# Epoch 50/50
# 1/1 [==============================] - 0s 391ms/step - loss: 0.0228 - accuracy: 1.0000 - val_loss: 0.2911 - val_accuracy: 0.9062
# — val_f1: 0.9035 — val_precision: 0.9147 — val_recall: 0.9062
