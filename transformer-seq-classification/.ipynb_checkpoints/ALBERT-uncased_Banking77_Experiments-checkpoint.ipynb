# %% [markdown]
# __Project:__ Intent Recognition <br>
# __Sub-prj:__ Parametric Evaluation - _number of labels & data instances_ <br>
# __Experm:__ ALBERT-base <br>
# __Status:__ Version 1.0 <br>

# %% [markdown]
# #### Libraries

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import transformers
from transformers import AutoTokenizer
from transformers import TFAutoModelForSequenceClassification
import tensorflow as tf
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.callbacks import Callback
import sklearn
from sklearn.metrics import confusion_matrix,f1_score,precision_score,recall_score 
from tensorflow.keras import backend as K
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' 

print(f"Tensorflow version: {tf.__version__}")
print(f"Sklearn version: {sklearn.__version__}")
print(f"Transformers version: {transformers.__version__}")

physical_devices = tf.config.list_physical_devices('GPU') 
for device in physical_devices:
    tf.config.experimental.set_memory_growth(device, True)
    
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Tensorflow version: 2.5.0
# Sklearn version: 1.0
# Transformers version: 4.11.3
# Num GPUs Available:  1

# %% [markdown]
# #### I/O Files & Params

# %%
fl_train        = '../datasets/banking77/train.csv'
fl_test         = '../datasets/banking77/test.csv'

checkpoint      ='albert-base-v2'

experiment_grid = {
    'n_labels'  : [3],
    'n_train_inst': [3]
}

seed = 42
BIG_int = 10**21

# %% [markdown]
# #### Functions

# %%
class Metrics(Callback):
    def __init__(self, validation_data):
        super(Metrics, self).__init__()
        self.validation_data = validation_data
        
    def on_train_begin(self, logs={}):
        self.val_f1s = []
        self.val_recalls = []
        self.val_precisions = []
 
    def on_epoch_end(self, epoch, logs={}):
        val_predict = np.argmax(tf.nn.softmax(self.model.predict(self.validation_data[0]).logits),1)
        val_targ = self.validation_data[1]
        val_f1 = f1_score(val_targ, val_predict, average='macro')
        val_recall = recall_score(val_targ, val_predict, average='macro')
        val_precision = precision_score(val_targ, val_predict, average='macro')
        logs['val_f1'] = val_f1
        logs['val_recall'] = val_recall
        logs['val_precision'] = val_precision
        print (f'— val_f1: {round(val_f1,4)} — val_precision: {round(val_precision,4)} — val_recall: {round(val_recall,4)}')
        return

def select_data_instances(train, test, col_label, n_labels=None, n_train_inst=None):
    if n_labels is None:
        n_labels = len(train.loc[:,col_label].unique())
    if n_train_inst is None:
        n_train_inst = BIG_int 
        
    select_labels = np.array(train.loc[:,col_label].value_counts()[0:n_labels].index)
    select_train  = train.loc[train[col_label].isin(select_labels),:].reset_index(drop=True)
    subset_train  = pd.DataFrame(columns=select_train.columns)
    for label in select_labels:
        temp_train   = select_train.loc[select_train[col_label]==label,:].reset_index(drop=True)
        select_indx  = np.random.choice(range(len(temp_train)),min(n_train_inst,len(temp_train)))
        temp_train   = temp_train.iloc[select_indx,:]
        subset_train = subset_train.append(temp_train)
    subset_train = subset_train.sample(frac=1).reset_index(drop=True)
    select_test  = test.loc[test[col_label].isin(select_labels),:].reset_index(drop=True)
    select_test  = select_test.sample(frac=1).reset_index(drop=True)
    return subset_train, select_test 

def factorize_data(train, test, col_label,return_keys=False):
    train_labels, levels = pd.factorize(train.loc[:,col_label])
    categs = pd.concat([train.loc[:,col_label],pd.Series(train_labels)],axis=1).groupby(col_label).mean().index
    labels = pd.concat([train.loc[:,col_label],pd.Series(train_labels)],axis=1).groupby(col_label).mean().values.T[0]
    label_keys=dict(zip(categs,labels))
    test_labels = test.loc[:,col_label].map(lambda x: label_keys[x])
    train.loc[:,col_label]=train_labels
    test.loc[:,col_label]=test_labels
    if return_keys:
        return train, test, label_keys
    else:
        return train, test
    
def tokenize_encode_data(train,test,col_text,col_label,checkpoint,
                         truncation_flag=True, padding_flag=True, return_tensors_opt='np'):
    train_sentences = list(train.loc[:,col_text])
    test_sentences  = list(test.loc[:,col_text])
    train_labels    = list(train.loc[:,col_label])
    test_labels     = list(test.loc[:,col_label])
    tokenizer       = AutoTokenizer.from_pretrained(checkpoint)
    train_encodings = tokenizer(train_sentences, truncation=truncation_flag,
                                padding=padding_flag, return_tensors=return_tensors_opt)
    test_encodings  = tokenizer(test_sentences, truncation=truncation_flag,
                                padding=padding_flag, return_tensors=return_tensors_opt)
    return train_encodings.data, train_labels, test_encodings.data, test_labels 

def transformer_model_compile(checkpoint,n_labels,lr=5e-5):
    model = TFAutoModelForSequenceClassification.from_pretrained(checkpoint, num_labels=n_labels)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
                  loss=SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])
    return model

def transformer_model_fit(model, train_encodings, train_labels, test_encodings, test_labels,epochs=10,batch_size=64):
    history = model.fit(train_encodings,np.array(train_labels),epochs=epochs,batch_size=batch_size,
          validation_data=(test_encodings, np.array(test_labels)),callbacks=[Metrics(validation_data)])
    return history, model

def make_plots(df):  
    sns.set_style("whitegrid")
    sns.set(rc={'figure.figsize':(10,6)})
    sns.set_context("talk")
    sns.lineplot(x="sample_size", y="val_f1", hue="num_categ", marker='o', data=df, legend="full")
    plt.show()
    sns.lineplot(hue="sample_size", y="val_f1", x="num_categ", marker='o', data=df, legend="full")

# %%
np.random.seed(seed)
train_orig = pd.read_csv(fl_train)
test_orig  = pd.read_csv(fl_test)

Big_Matrix      = pd.DataFrame(columns=['num_categ','sample_size','val_f1'])

iexp=0
for ilab in experiment_grid['n_labels']:
    compiled_model = transformer_model_compile(checkpoint,ilab)
    for i_ninst in experiment_grid['n_train_inst']:
        iexp+=1
        train, test = select_data_instances(train_orig, test_orig, 'category', ilab, i_ninst)
        train, test = factorize_data(train, test, 'category')
        print(f'\nExperiment {iexp} with {ilab} labels and {i_ninst} instances')
        print(f'\nsize of training dataset: {len(train)}')
        print(f'size of testing dataset: {len(test)}')
        colors = sns.color_palette('pastel')[0:ilab]
        _ = plt.pie(list(train['category'].value_counts()), 
                    labels = list(train['category'].value_counts().index), 
                    colors = colors, autopct='%.0f%%')
        _ = plt.title('Classes')
        _ = plt.show()
        
        train_encodings, train_labels, test_encodings, test_labels = tokenize_encode_data(train,test,'text',
                                                                                          'category',checkpoint)
        validation_data                                            =(test_encodings, np.array(test_labels))
        
        history, fitted_model = transformer_model_fit(compiled_model,train_encodings,train_labels,
                                                      test_encodings, test_labels,epochs=50)

        fig, axes   = plt.subplots(1,3,figsize=(15,5))
        epoch_range = np.arange(1,len(history.history['loss'])+1)
        axes[0]   = sns.lineplot(ax=axes[0],x=epoch_range,y=history.history['loss'],label='Training Loss')
        axes[0]   = sns.lineplot(ax=axes[0],x=epoch_range,y=history.history['val_loss'],label='Validation Loss').set_title('Loss')
        axes[1]   = sns.lineplot(ax=axes[1],x=epoch_range,y=history.history['accuracy'],label='Training Accuracy')
        axes[1]   = sns.lineplot(ax=axes[1],x=epoch_range,y=history.history['val_accuracy'],label='Validation Accuracy').set_title('Accuracy')
        axes[2]   = sns.lineplot(ax=axes[2],x=epoch_range,y=history.history['val_precision'],label='Validation Precision')
        axes[2]   = sns.lineplot(ax=axes[2],x=epoch_range,y=history.history['val_recall'],label='Validation Recall')
        axes[2]   = sns.lineplot(ax=axes[2],x=epoch_range,y=history.history['val_f1'],label='Validation f1_score(macro)').set_title('Precision/Recall/f1_score')
        axes[1].set_ylim=(0, 1)
        axes[2].set_ylim=(0, 1)
        _         = plt.show()
        
        Big_Matrix.loc[iexp,'num_categ']    = ilab
        Big_Matrix.loc[iexp,'sample_size']  = i_ninst
        Big_Matrix.loc[iexp,'val_f1'] = np.max(history.history['val_f1'])
# Out:
# All model checkpoint layers were used when initializing TFAlbertForSequenceClassification.
#
# Some layers of TFAlbertForSequenceClassification were not initialized from the model checkpoint at albert-base-v2 and are newly initialized: ['classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Experiment 1 with 3 labels and 3 instances
#
# size of training dataset: 9
# size of testing dataset: 120
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\Windows\anaconda3\envs\tf2.5\lib\site-packages\tensorflow\python\ops\array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# 1/1 [==============================] - 12s 12s/step - loss: 1.1337 - accuracy: 0.3333 - val_loss: 1.1010 - val_accuracy: 0.3417
# — val_f1: 0.1861 — val_precision: 0.1983 — val_recall: 0.3417
# Epoch 2/50
# 1/1 [==============================] - 0s 432ms/step - loss: 1.0662 - accuracy: 0.4444 - val_loss: 1.0455 - val_accuracy: 0.5000
# — val_f1: 0.4979 — val_precision: 0.5161 — val_recall: 0.5
# Epoch 3/50
# 1/1 [==============================] - 0s 442ms/step - loss: 0.9493 - accuracy: 0.6667 - val_loss: 0.9740 - val_accuracy: 0.6917
# — val_f1: 0.6796 — val_precision: 0.7253 — val_recall: 0.6917
# Epoch 4/50
# 1/1 [==============================] - 0s 442ms/step - loss: 0.8475 - accuracy: 0.8889 - val_loss: 0.9414 - val_accuracy: 0.6917
# — val_f1: 0.6895 — val_precision: 0.7036 — val_recall: 0.6917
# Epoch 5/50
# 1/1 [==============================] - 0s 442ms/step - loss: 0.7944 - accuracy: 0.7778 - val_loss: 1.0832 - val_accuracy: 0.4000
# — val_f1: 0.2835 — val_precision: 0.3647 — val_recall: 0.4
# Epoch 6/50
# 1/1 [==============================] - 0s 440ms/step - loss: 1.0281 - accuracy: 0.4444 - val_loss: 0.8735 - val_accuracy: 0.6750
# — val_f1: 0.6266 — val_precision: 0.7911 — val_recall: 0.675
# Epoch 7/50
# 1/1 [==============================] - 0s 450ms/step - loss: 0.5499 - accuracy: 1.0000 - val_loss: 0.8198 - val_accuracy: 0.7000
# — val_f1: 0.678 — val_precision: 0.8343 — val_recall: 0.7
# Epoch 8/50
# 1/1 [==============================] - 0s 447ms/step - loss: 0.4641 - accuracy: 1.0000 - val_loss: 0.7772 - val_accuracy: 0.7250
# — val_f1: 0.7156 — val_precision: 0.8414 — val_recall: 0.725
# Epoch 9/50
# 1/1 [==============================] - 0s 464ms/step - loss: 0.3904 - accuracy: 1.0000 - val_loss: 0.7867 - val_accuracy: 0.7667
# — val_f1: 0.7478 — val_precision: 0.8392 — val_recall: 0.7667
# Epoch 10/50
# 1/1 [==============================] - 0s 486ms/step - loss: 0.3247 - accuracy: 1.0000 - val_loss: 0.7357 - val_accuracy: 0.7500
# — val_f1: 0.7408 — val_precision: 0.8501 — val_recall: 0.75
# Epoch 11/50
# 1/1 [==============================] - 0s 448ms/step - loss: 0.2848 - accuracy: 1.0000 - val_loss: 0.6687 - val_accuracy: 0.7917
# — val_f1: 0.7934 — val_precision: 0.8646 — val_recall: 0.7917
# Epoch 12/50
# 1/1 [==============================] - 0s 464ms/step - loss: 0.2381 - accuracy: 1.0000 - val_loss: 0.6566 - val_accuracy: 0.8167
# — val_f1: 0.8144 — val_precision: 0.876 — val_recall: 0.8167
# Epoch 13/50
# 1/1 [==============================] - 0s 468ms/step - loss: 0.1744 - accuracy: 1.0000 - val_loss: 0.6470 - val_accuracy: 0.8083
# — val_f1: 0.7996 — val_precision: 0.8571 — val_recall: 0.8083
# Epoch 14/50
# 1/1 [==============================] - 0s 439ms/step - loss: 0.1710 - accuracy: 1.0000 - val_loss: 0.6085 - val_accuracy: 0.8250
# — val_f1: 0.8182 — val_precision: 0.8756 — val_recall: 0.825
# Epoch 15/50
# 1/1 [==============================] - 0s 470ms/step - loss: 0.1259 - accuracy: 1.0000 - val_loss: 0.5768 - val_accuracy: 0.8333
# — val_f1: 0.8292 — val_precision: 0.8738 — val_recall: 0.8333
# Epoch 16/50
# 1/1 [==============================] - 0s 432ms/step - loss: 0.1158 - accuracy: 1.0000 - val_loss: 0.5642 - val_accuracy: 0.8250
# — val_f1: 0.8212 — val_precision: 0.8644 — val_recall: 0.825
# Epoch 17/50
# 1/1 [==============================] - 0s 471ms/step - loss: 0.1091 - accuracy: 1.0000 - val_loss: 0.5546 - val_accuracy: 0.8167
# — val_f1: 0.8124 — val_precision: 0.8529 — val_recall: 0.8167
# Epoch 18/50
# 1/1 [==============================] - 0s 439ms/step - loss: 0.0970 - accuracy: 1.0000 - val_loss: 0.5469 - val_accuracy: 0.8417
# — val_f1: 0.8364 — val_precision: 0.8689 — val_recall: 0.8417
# Epoch 19/50
# 1/1 [==============================] - 0s 486ms/step - loss: 0.0761 - accuracy: 1.0000 - val_loss: 0.5286 - val_accuracy: 0.8417
# — val_f1: 0.8364 — val_precision: 0.8689 — val_recall: 0.8417
# Epoch 20/50
# 1/1 [==============================] - 0s 432ms/step - loss: 0.0765 - accuracy: 1.0000 - val_loss: 0.5055 - val_accuracy: 0.8500
# — val_f1: 0.8442 — val_precision: 0.8712 — val_recall: 0.85
# Epoch 21/50
# 1/1 [==============================] - 0s 454ms/step - loss: 0.0608 - accuracy: 1.0000 - val_loss: 0.4907 - val_accuracy: 0.8500
# — val_f1: 0.8442 — val_precision: 0.8712 — val_recall: 0.85
# Epoch 22/50
# 1/1 [==============================] - 0s 433ms/step - loss: 0.0601 - accuracy: 1.0000 - val_loss: 0.4909 - val_accuracy: 0.8500
# — val_f1: 0.8442 — val_precision: 0.8712 — val_recall: 0.85
# Epoch 23/50
# 1/1 [==============================] - 0s 431ms/step - loss: 0.0510 - accuracy: 1.0000 - val_loss: 0.4936 - val_accuracy: 0.8583
# — val_f1: 0.8523 — val_precision: 0.8857 — val_recall: 0.8583
# Epoch 24/50
# 1/1 [==============================] - 0s 455ms/step - loss: 0.0452 - accuracy: 1.0000 - val_loss: 0.4931 - val_accuracy: 0.8667
# — val_f1: 0.8596 — val_precision: 0.8913 — val_recall: 0.8667
# Epoch 25/50
# 1/1 [==============================] - 0s 464ms/step - loss: 0.0411 - accuracy: 1.0000 - val_loss: 0.4862 - val_accuracy: 0.8583
# — val_f1: 0.8515 — val_precision: 0.8769 — val_recall: 0.8583
# Epoch 26/50
# 1/1 [==============================] - 0s 432ms/step - loss: 0.0334 - accuracy: 1.0000 - val_loss: 0.4762 - val_accuracy: 0.8583
# — val_f1: 0.8515 — val_precision: 0.8769 — val_recall: 0.8583
# Epoch 27/50
# 1/1 [==============================] - 0s 447ms/step - loss: 0.0291 - accuracy: 1.0000 - val_loss: 0.4687 - val_accuracy: 0.8583
# — val_f1: 0.8515 — val_precision: 0.8769 — val_recall: 0.8583
# Epoch 28/50
# 1/1 [==============================] - 0s 478ms/step - loss: 0.0293 - accuracy: 1.0000 - val_loss: 0.4693 - val_accuracy: 0.8583
# — val_f1: 0.8515 — val_precision: 0.8769 — val_recall: 0.8583
# Epoch 29/50
# 1/1 [==============================] - 0s 439ms/step - loss: 0.0253 - accuracy: 1.0000 - val_loss: 0.4793 - val_accuracy: 0.8583
# — val_f1: 0.8515 — val_precision: 0.8769 — val_recall: 0.8583
# Epoch 30/50
# 1/1 [==============================] - 0s 438ms/step - loss: 0.0235 - accuracy: 1.0000 - val_loss: 0.4937 - val_accuracy: 0.8500
# — val_f1: 0.8429 — val_precision: 0.8673 — val_recall: 0.85
# Epoch 31/50
# 1/1 [==============================] - 0s 448ms/step - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.5038 - val_accuracy: 0.8500
# — val_f1: 0.8429 — val_precision: 0.8673 — val_recall: 0.85
# Epoch 32/50
# 1/1 [==============================] - 0s 486ms/step - loss: 0.0221 - accuracy: 1.0000 - val_loss: 0.5080 - val_accuracy: 0.8500
# — val_f1: 0.8429 — val_precision: 0.8673 — val_recall: 0.85
# Epoch 33/50
# 1/1 [==============================] - 0s 439ms/step - loss: 0.0197 - accuracy: 1.0000 - val_loss: 0.5081 - val_accuracy: 0.8500
# — val_f1: 0.8429 — val_precision: 0.8673 — val_recall: 0.85
# Epoch 34/50
# 1/1 [==============================] - 0s 448ms/step - loss: 0.0161 - accuracy: 1.0000 - val_loss: 0.5074 - val_accuracy: 0.8500
# — val_f1: 0.8429 — val_precision: 0.8673 — val_recall: 0.85
# Epoch 35/50
# 1/1 [==============================] - 0s 475ms/step - loss: 0.0169 - accuracy: 1.0000 - val_loss: 0.5082 - val_accuracy: 0.8500
# — val_f1: 0.8429 — val_precision: 0.8673 — val_recall: 0.85
# Epoch 36/50
# 1/1 [==============================] - 0s 453ms/step - loss: 0.0151 - accuracy: 1.0000 - val_loss: 0.5123 - val_accuracy: 0.8500
# — val_f1: 0.8429 — val_precision: 0.8673 — val_recall: 0.85
# Epoch 37/50
# 1/1 [==============================] - 0s 464ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.5193 - val_accuracy: 0.8417
# — val_f1: 0.8349 — val_precision: 0.8595 — val_recall: 0.8417
# Epoch 38/50
# 1/1 [==============================] - 0s 455ms/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.5256 - val_accuracy: 0.8417
# — val_f1: 0.8349 — val_precision: 0.8595 — val_recall: 0.8417
# Epoch 39/50
# 1/1 [==============================] - 0s 433ms/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.5302 - val_accuracy: 0.8417
# — val_f1: 0.8349 — val_precision: 0.8595 — val_recall: 0.8417
# Epoch 40/50
# 1/1 [==============================] - 0s 448ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.5337 - val_accuracy: 0.8417
# — val_f1: 0.8349 — val_precision: 0.8595 — val_recall: 0.8417
# Epoch 41/50
# 1/1 [==============================] - 0s 439ms/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.5375 - val_accuracy: 0.8417
# — val_f1: 0.8349 — val_precision: 0.8595 — val_recall: 0.8417
# Epoch 42/50
# 1/1 [==============================] - 0s 441ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.5412 - val_accuracy: 0.8417
# — val_f1: 0.8349 — val_precision: 0.8595 — val_recall: 0.8417
# Epoch 43/50
# 1/1 [==============================] - 0s 439ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.5442 - val_accuracy: 0.8417
# — val_f1: 0.8349 — val_precision: 0.8595 — val_recall: 0.8417
# Epoch 44/50
# 1/1 [==============================] - 0s 463ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.5449 - val_accuracy: 0.8417
# — val_f1: 0.8349 — val_precision: 0.8595 — val_recall: 0.8417
# Epoch 45/50
# 1/1 [==============================] - 1s 509ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.5436 - val_accuracy: 0.8417
# — val_f1: 0.8349 — val_precision: 0.8595 — val_recall: 0.8417
# Epoch 46/50
# 1/1 [==============================] - 1s 535ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.5421 - val_accuracy: 0.8417
# — val_f1: 0.8349 — val_precision: 0.8595 — val_recall: 0.8417
# Epoch 47/50
# 1/1 [==============================] - 0s 447ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.5403 - val_accuracy: 0.8417
# — val_f1: 0.8349 — val_precision: 0.8595 — val_recall: 0.8417
# Epoch 48/50
# 1/1 [==============================] - 0s 454ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.5373 - val_accuracy: 0.8417
# — val_f1: 0.8349 — val_precision: 0.8595 — val_recall: 0.8417
# Epoch 49/50
# 1/1 [==============================] - 0s 463ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.5357 - val_accuracy: 0.8417
# — val_f1: 0.8349 — val_precision: 0.8595 — val_recall: 0.8417
# Epoch 50/50
# 1/1 [==============================] - 0s 448ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.5350 - val_accuracy: 0.8417
# — val_f1: 0.8349 — val_precision: 0.8595 — val_recall: 0.8417
